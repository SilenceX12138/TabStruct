# %% [markdown]
# # Causal Discovery for datasets with mixed feature types

# %%
import matplotlib.pyplot as plt
import networkx as nx
import numpy as np
import pandas as pd
import pgmpy
from pgmpy.estimators import PC, BicScore, HillClimbSearch
from pgmpy.models import BayesianNetwork
from sklearn.datasets import make_classification
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.preprocessing import OneHotEncoder

# %% [markdown]
# ## Data preparation

# %%
from openml import datasets

# dataset = datasets.get_dataset(179)
dataset = datasets.get_dataset(14)

# %%
df = dataset.get_data(target=dataset.default_target_attribute)[0]
df.info()
# Out:
# INFO:openml.datasets.dataset:pickle load data mfeat-fourier
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 76 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   att1    2000 non-null   float64
#  1   att2    2000 non-null   float64
#  2   att3    2000 non-null   float64
#  3   att4    2000 non-null   float64
#  4   att5    2000 non-null   float64
#  5   att6    2000 non-null   float64
#  6   att7    2000 non-null   float64
#  7   att8    2000 non-null   float64
#  8   att9    2000 non-null   float64
#  9   att10   2000 non-null   float64
#  10  att11   2000 non-null   float64
#  11  att12   2000 non-null   float64
#  12  att13   2000 non-null   float64
#  13  att14   2000 non-null   float64
#  14  att15   2000 non-null   float64
#  15  att16   2000 non-null   float64
#  16  att17   2000 non-null   float64
#  17  att18   2000 non-null   float64
#  18  att19   2000 non-null   float64
#  19  att20   2000 non-null   float64
#  20  att21   2000 non-null   float64
#  21  att22   2000 non-null   float64
#  22  att23   2000 non-null   float64
#  23  att24   2000 non-null   float64
#  24  att25   2000 non-null   float64
#  25  att26   2000 non-null   float64
#  26  att27   2000 non-null   float64
#  27  att28   2000 non-null   float64
#  28  att29   2000 non-null   float64
#  29  att30   2000 non-null   float64
#  30  att31   2000 non-null   float64
#  31  att32   2000 non-null   float64
#  32  att33   2000 non-null   float64
#  33  att34   2000 non-null   float64
#  34  att35   2000 non-null   float64
#  35  att36   2000 non-null   float64
#  36  att37   2000 non-null   float64
#  37  att38   2000 non-null   float64
#  38  att39   2000 non-null   float64
#  39  att40   2000 non-null   float64
#  40  att41   2000 non-null   float64
#  41  att42   2000 non-null   float64
#  42  att43   2000 non-null   float64
#  43  att44   2000 non-null   float64
#  44  att45   2000 non-null   float64
#  45  att46   2000 non-null   float64
#  46  att47   2000 non-null   float64
#  47  att48   2000 non-null   float64
#  48  att49   2000 non-null   float64
#  49  att50   2000 non-null   float64
#  50  att51   2000 non-null   float64
#  51  att52   2000 non-null   float64
#  52  att53   2000 non-null   float64
#  53  att54   2000 non-null   float64
#  54  att55   2000 non-null   float64
#  55  att56   2000 non-null   float64
#  56  att57   2000 non-null   float64
#  57  att58   2000 non-null   float64
#  58  att59   2000 non-null   float64
#  59  att60   2000 non-null   float64
#  60  att61   2000 non-null   float64
#  61  att62   2000 non-null   float64
#  62  att63   2000 non-null   float64
#  63  att64   2000 non-null   float64
#  64  att65   2000 non-null   float64
#  65  att66   2000 non-null   float64
#  66  att67   2000 non-null   float64
#  67  att68   2000 non-null   float64
#  68  att69   2000 non-null   float64
#  69  att70   2000 non-null   float64
#  70  att71   2000 non-null   float64
#  71  att72   2000 non-null   float64
#  72  att73   2000 non-null   float64
#  73  att74   2000 non-null   float64
#  74  att75   2000 non-null   float64
#  75  att76   2000 non-null   float64
# dtypes: float64(76)
# memory usage: 1.2 MB

# %%
# === Preprocess the data ===
# Encode the categorical data
cat_encoder = OneHotEncoder()
cat_data = cat_encoder.fit_transform(df.select_dtypes(include=["object", "category"]))
cat_data = pd.DataFrame(
    cat_data.toarray(),
    columns=cat_encoder.get_feature_names_out(df.select_dtypes(include=["object", "category"]).columns),
)
df = df.drop(columns=df.select_dtypes(include=["object", "category"]).columns)
df = pd.concat([df, cat_data], axis=1)

df
# Out:
#           att1      att2      att3      att4      att5      att6      att7  \
# 0     0.065882  0.197312  0.103826  0.270362  0.616078  0.035856  0.424572
# 1     0.049142  0.175971  0.105515  0.227095  0.599280  0.041217  0.431078
# 2     0.034172  0.227649  0.108766  0.127697  0.612494  0.056554  0.470639
# 3     0.062336  0.217979  0.080243  0.289592  0.546316  0.045779  0.425545
# 4     0.061970  0.198358  0.111239  0.253460  0.608455  0.023631  0.415246
# ...        ...       ...       ...       ...       ...       ...       ...
# 1995  0.171874  0.221525  0.426470  0.077220  0.264413  0.220274  0.452574
# 1996  0.152025  0.347439  0.323534  0.087706  0.427077  0.313656  0.371549
# 1997  0.335606  0.318426  0.257948  0.225381  0.417769  0.123067  0.333455
# 1998  0.253910  0.171202  0.302622  0.181066  0.326383  0.167960  0.417409
# 1999  0.271575  0.149037  0.232753  0.197720  0.236424  0.187395  0.467213
#
#           att8      att9     att10  ...     att67     att68     att69  \
# 0     0.089701  0.367773  0.037065  ...  0.123448  0.113374  0.074343
# 1     0.096801  0.326739  0.059661  ...  0.045310  0.069337  0.045386
# 2     0.041903  0.324267  0.044569  ...  0.019858  0.218842  0.041087
# 3     0.022841  0.331454  0.119052  ...  0.083995  0.085479  0.087658
# 4     0.091866  0.309310  0.049142  ...  0.021004  0.106960  0.032283
# ...        ...       ...       ...  ...       ...       ...       ...
# 1995  0.161113  0.356788  0.081889  ...  0.108996  0.197440  0.197778
# 1996  0.262768  0.396422  0.124391  ...  0.212160  0.161606  0.033621
# 1997  0.342044  0.398151  0.079550  ...  0.236628  0.121659  0.316333
# 1998  0.399065  0.266153  0.097131  ...  0.155442  0.168154  0.147167
# 1999  0.385117  0.191292  0.149162  ...  0.140143  0.225634  0.061724
#
#          att70     att71     att72     att73     att74     att75     att76
# 0     0.281666  0.067795  0.344182  0.038963  0.394366  0.049971  0.344871
# 1     0.254264  0.045447  0.335659  0.021719  0.445277  0.083978  0.354092
# 2     0.360464  0.047154  0.377408  0.052099  0.445029  0.071234  0.261465
# 3     0.151880  0.075950  0.293462  0.022675  0.408291  0.063010  0.401376
# 4     0.248565  0.015674  0.386276  0.039481  0.434701  0.069218  0.405403
# ...        ...       ...       ...       ...       ...       ...       ...
# 1995  0.205866  0.138887  0.160848  0.126190  0.247345  0.239117  0.136807
# 1996  0.173155  0.295227  0.259417  0.345691  0.068303  0.158352  0.282327
# 1997  0.244846  0.132893  0.042988  0.250740  0.141576  0.038776  0.114591
# 1998  0.268675  0.199125  0.128708  0.285220  0.230322  0.103664  0.130003
# 1999  0.267944  0.251182  0.170772  0.322067  0.275769  0.021074  0.085241
#
# [2000 rows x 76 columns]

# %% [markdown]
# ## PC algorithm

# %%
# estimated_pdag = PC(df).estimate(ci_test='pillai')
# estimated_pdag.to_graphviz().draw('adult_pillai.png', prog='dot')

# %% [markdown]
# ## MMHC algorithm

# %%
from pgmpy.estimators import MmhcEstimator

est = MmhcEstimator(df)
model = est.estimate()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 4
#       1 from pgmpy.estimators import MmhcEstimator
#       3 est = MmhcEstimator(df)
# ----> 4 model = est.estimate()
#
# File ~/.local/lib/python3.10/site-packages/pgmpy/estimators/MmhcEstimator.py:82, in MmhcEstimator.estimate(self, scoring_method, tabu_length, significance_level)
#      79 if scoring_method is None:
#      80     scoring_method = BDeuScore(self.data, equivalent_sample_size=10)
# ---> 82 skel = self.mmpc(significance_level)
#      84 hc = HillClimbSearch(self.data)
#      86 model = hc.estimate(
#      87     scoring_method=scoring_method,
#      88     white_list=skel.to_directed().edges(),
#      89     tabu_length=tabu_length,
#      90 )
#
# File ~/.local/lib/python3.10/site-packages/pgmpy/estimators/MmhcEstimator.py:184, in MmhcEstimator.mmpc(self, significance_level)
#     182 # Forward Phase
#     183 while True:
# --> 184     new_neighbor, new_neighbor_min_assoc = max_min_heuristic(
#     185         node, neighbors[node]
#     186     )
#     187     if new_neighbor_min_assoc > 0:
#     188         neighbors[node].append(new_neighbor)
#
# File ~/.local/lib/python3.10/site-packages/pgmpy/estimators/MmhcEstimator.py:170, in MmhcEstimator.mmpc.<locals>.max_min_heuristic(X, Zs)
#     167 best_Y = None
#     169 for Y in set(nodes) - set(Zs + [X]):
# --> 170     min_assoc_val = min_assoc(X, Y, Zs)
#     171     if min_assoc_val >= max_min_assoc:
#     172         best_Y = Y
#
# File ~/.local/lib/python3.10/site-packages/pgmpy/estimators/MmhcEstimator.py:162, in MmhcEstimator.mmpc.<locals>.min_assoc(X, Y, Zs)
#     160 def min_assoc(X, Y, Zs):
#     161     "Minimal association of X, Y given any subset of Zs."
# --> 162     return min(assoc(X, Y, Zs_subset) for Zs_subset in powerset(Zs))
#
# File ~/.local/lib/python3.10/site-packages/pgmpy/estimators/MmhcEstimator.py:162, in <genexpr>(.0)
#     160 def min_assoc(X, Y, Zs):
#     161     "Minimal association of X, Y given any subset of Zs."
# --> 162     return min(assoc(X, Y, Zs_subset) for Zs_subset in powerset(Zs))
#
# File ~/.local/lib/python3.10/site-packages/pgmpy/estimators/MmhcEstimator.py:158, in MmhcEstimator.mmpc.<locals>.assoc(X, Y, Zs)
#     154 def assoc(X, Y, Zs):
#     155     """Measure for (conditional) association between variables. Use negative
#     156     p-value of independence test.
#     157     """
# --> 158     return 1 - chi_square(X, Y, Zs, self.data, boolean=False)[1]
#
# File ~/.local/lib/python3.10/site-packages/pgmpy/estimators/CITests.py:97, in chi_square(X, Y, Z, data, boolean, **kwargs)
#      37 def chi_square(X, Y, Z, data, boolean=True, **kwargs):
#      38     r"""
#      39     Chi-square conditional independence test.
#      40     Tests the null hypothesis that X is independent from Y given Zs.
#    (...)
#      95     False
#      96     """
# ---> 97     return power_divergence(
#      98         X=X, Y=Y, Z=Z, data=data, boolean=boolean, lambda_="pearson", **kwargs
#      99     )
#
# File ~/.local/lib/python3.10/site-packages/pgmpy/estimators/CITests.py:553, in power_divergence(X, Y, Z, data, boolean, lambda_, **kwargs)
#     550 for z_state, df in data.groupby(Z):
#     551     try:
#     552         c, _, d, _ = stats.chi2_contingency(
# --> 553             df.groupby([X, Y]).size().unstack(Y, fill_value=0), lambda_=lambda_
#     554         )
#     555         chi += c
#     556         dof += d
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/series.py:4615, in Series.unstack(self, level, fill_value, sort)
#    4570 """
#    4571 Unstack, also known as pivot, Series with MultiIndex to produce DataFrame.
#    4572
#    (...)
#    4611 b    2    4
#    4612 """
#    4613 from pandas.core.reshape.reshape import unstack
# -> 4615 return unstack(self, level, fill_value, sort)
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/reshape/reshape.py:517, in unstack(obj, level, fill_value, sort)
#     515 if is_1d_only_ea_dtype(obj.dtype):
#     516     return _unstack_extension_series(obj, level, fill_value, sort=sort)
# --> 517 unstacker = _Unstacker(
#     518     obj.index, level=level, constructor=obj._constructor_expanddim, sort=sort
#     519 )
#     520 return unstacker.get_result(
#     521     obj._values, value_columns=None, fill_value=fill_value
#     522 )
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/reshape/reshape.py:154, in _Unstacker.__init__(self, index, level, constructor, sort)
#     146 if num_cells > np.iinfo(np.int32).max:
#     147     warnings.warn(
#     148         f"The following operation may generate {num_cells} cells "
#     149         f"in the resulting pandas object.",
#     150         PerformanceWarning,
#     151         stacklevel=find_stack_level(),
#     152     )
# --> 154 self._make_selectors()
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/reshape/reshape.py:195, in _Unstacker._make_selectors(self)
#     192 new_levels = self.new_index_levels
#     194 # make the mask
# --> 195 remaining_labels = self.sorted_labels[:-1]
#     196 level_sizes = tuple(len(x) for x in new_levels)
#     198 comp_index, obs_ids = get_compressed_ids(remaining_labels, level_sizes)
#
# File properties.pyx:36, in pandas._libs.properties.CachedProperty.__get__()
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/reshape/reshape.py:178, in _Unstacker.sorted_labels(self)
#     176 @cache_readonly
#     177 def sorted_labels(self) -> list[np.ndarray]:
# --> 178     indexer, to_sort = self._indexer_and_to_sort
#     179     if self.sort:
#     180         return [line.take(indexer) for line in to_sort]
#
# File properties.pyx:36, in pandas._libs.properties.CachedProperty.__get__()
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/reshape/reshape.py:170, in _Unstacker._indexer_and_to_sort(self)
#     167 to_sort = codes[:v] + codes[v + 1 :] + [codes[v]]
#     168 sizes = tuple(len(x) for x in levs[:v] + levs[v + 1 :] + [levs[v]])
# --> 170 comp_index, obs_ids = get_compressed_ids(to_sort, sizes)
#     171 ngroups = len(obs_ids)
#     173 indexer = get_group_index_sorter(comp_index, ngroups)
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/sorting.py:235, in get_compressed_ids(labels, sizes)
#     217 """
#     218 Group_index is offsets into cartesian product of all possible labels. This
#     219 space can be huge, so this function compresses it, by computing offsets
#    (...)
#     232     obs_group_ids
#     233 """
#     234 ids = get_group_index(labels, sizes, sort=True, xnull=False)
# --> 235 return compress_group_index(ids, sort=True)
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/sorting.py:695, in compress_group_index(group_index, sort)
#     687 def compress_group_index(
#     688     group_index: npt.NDArray[np.int64], sort: bool = True
#     689 ) -> tuple[npt.NDArray[np.int64], npt.NDArray[np.int64]]:
#     690     """
#     691     Group_index is offsets into cartesian product of all possible labels. This
#     692     space can be huge, so this function compresses it, by computing offsets
#     693     (comp_ids) into the list of unique labels (obs_group_ids).
#     694     """
# --> 695     if len(group_index) and np.all(group_index[1:] >= group_index[:-1]):
#     696         # GH 53806: fast path for sorted group_index
#     697         unique_mask = np.concatenate(
#     698             [group_index[:1] > -1, group_index[1:] != group_index[:-1]]
#     699         )
#     700         comp_ids = unique_mask.cumsum()
#
# File ~/.local/lib/python3.10/site-packages/numpy/core/fromnumeric.py:2504, in all(a, axis, out, keepdims, where)
#    2421 @array_function_dispatch(_all_dispatcher)
#    2422 def all(a, axis=None, out=None, keepdims=np._NoValue, *, where=np._NoValue):
#    2423     """
#    2424     Test whether all array elements along a given axis evaluate to True.
#    2425
#    (...)
#    2502
#    2503     """
# -> 2504     return _wrapreduction(a, np.logical_and, 'all', axis, None, out,
#    2505                           keepdims=keepdims, where=where)
#
# File ~/.local/lib/python3.10/site-packages/numpy/core/fromnumeric.py:75, in _wrapreduction(obj, ufunc, method, axis, dtype, out, **kwargs)
#      71 def _wrapreduction(obj, ufunc, method, axis, dtype, out, **kwargs):
#      72     passkwargs = {k: v for k, v in kwargs.items()
#      73                   if v is not np._NoValue}
# ---> 75     if type(obj) is not mu.ndarray:
#      76         try:
#      77             reduction = getattr(obj, method)
#
# KeyboardInterrupt:

# %% [markdown]
# ## Tree search algorithm

# %%
from pgmpy.estimators import TreeSearch

est = TreeSearch(df)
model = est.estimate()
model.to_graphviz().draw('adult_tree.png', prog='dot')
# Out:
# Building tree:   0%|          | 0/2850.0 [00:00<?, ?it/s]
# /home/xj265/.local/lib/python3.10/site-packages/sklearn/metrics/cluster/_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and continuous values for target
#   warnings.warn(msg, UserWarning)
# /home/xj265/.local/lib/python3.10/site-packages/sklearn/metrics/cluster/_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and continuous values for target
#   warnings.warn(msg, UserWarning)
# /home/xj265/.local/lib/python3.10/site-packages/sklearn/metrics/cluster/_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and continuous values for target
#   warnings.warn(msg, UserWarning)
# /home/xj265/.local/lib/python3.10/site-packages/sklearn/metrics/cluster/_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and continuous values for target
#   warnings.warn(msg, UserWarning)
# /home/xj265/.local/lib/python3.10/site-packages/sklearn/metrics/cluster/_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and continuous values for target
#   warnings.warn(msg, UserWarning)
# /home/xj265/.local/lib/python3.10/site-packages/sklearn/metrics/cluster/_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and continuous values for target
#   warnings.warn(msg, UserWarning)
# /home/xj265/.local/lib/python3.10/site-packages/sklearn/metrics/cluster/_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and continuous values for target
#   warnings.warn(msg, UserWarning)
# /home/xj265/.local/lib/python3.10/site-packages/sklearn/metrics/cluster/_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and continuous values for target
#   warnings.warn(msg, UserWarning)
# /home/xj265/.local/lib/python3.10/site-packages/sklearn/metrics/cluster/_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and continuous values for target
#   warnings.warn(msg, UserWarning)
# /home/xj265/.local/lib/python3.10/site-packages/sklearn/metrics/cluster/_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and continuous values for target
#   warnings.warn(msg, UserWarning)
# /home/xj265/.local/lib/python3.10/site-packages/sklearn/metrics/cluster/_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and continuous values for target
#   warnings.warn(msg, UserWarning)
# /home/xj265/.local/lib/python3.10/site-packages/sklearn/metrics/cluster/_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and continuous values for target
#   warnings.warn(msg, UserWarning)
# /home/xj265/.local/lib/python3.10/site-packages/sklearn/metrics/cluster/_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and continuous values for target
#   warnings.warn(msg, UserWarning)
# /home/xj265/.local/lib/python3.10/site-packages/sklearn/metrics/cluster/_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and continuous values for target
#   warnings.warn(msg, UserWarning)
# /home/xj265/.local/lib/python3.10/site-packages/sklearn/metrics/cluster/_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and continuous values for target
#   warnings.warn(msg, UserWarning)
# /home/xj265/.local/lib/python3.10/site-packages/sklearn/metrics/cluster/_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and continuous values for target
#   warnings.warn(msg, UserWarning)
# /home/xj265/.local/lib/python3.10/site-packages/sklearn/metrics/cluster/_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and continuous values for target
#   warnings.warn(msg, UserWarning)
# /home/xj265/.local/lib/python3.10/site-packages/sklearn/metrics/cluster/_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and continuous values for target
#   warnings.warn(msg, UserWarning)
# /home/xj265/.local/lib/python3.10/site-packages/sklearn/metrics/cluster/_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and continuous values for target
#   warnings.warn(msg, UserWarning)
# /home/xj265/.local/lib/python3.10/site-packages/sklearn/metrics/cluster/_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and continuous values for target
#   warnings.warn(msg, UserWarning)
# /home/xj265/.local/lib/python3.10/site-packages/sklearn/metrics/cluster/_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and continuous values for target
#   warnings.warn(msg, UserWarning)
# /home/xj265/.local/lib/python3.10/site-packages/sklearn/metrics/cluster/_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and continuous values for target
#   warnings.warn(msg, UserWarning)
# /home/xj265/.local/lib/python3.10/site-packages/sklearn/metrics/cluster/_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and continuous values for target
#   warnings.warn(msg, UserWarning)
# /home/xj265/.local/lib/python3.10/site-packages/sklearn/metrics/cluster/_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and continuous values for target
#   warnings.warn(msg, UserWarning)
# /home/xj265/.local/lib/python3.10/site-packages/sklearn/metrics/cluster/_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and continuous values for target
#   warnings.warn(msg, UserWarning)
# /home/xj265/.local/lib/python3.10/site-packages/sklearn/metrics/cluster/_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and continuous values for target
#   warnings.warn(msg, UserWarning)
# /home/xj265/.local/lib/python3.10/site-packages/sklearn/metrics/cluster/_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and continuous values for target
#   warnings.warn(msg, UserWarning)
# /home/xj265/.local/lib/python3.10/site-packages/sklearn/metrics/cluster/_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and continuous values for target
#   warnings.warn(msg, UserWarning)
# /home/xj265/.local/lib/python3.10/site-packages/sklearn/metrics/cluster/_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and continuous values for target
#   warnings.warn(msg, UserWarning)
# /home/xj265/.local/lib/python3.10/site-packages/sklearn/metrics/cluster/_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and continuous values for target
#   warnings.warn(msg, UserWarning)
# /home/xj265/.local/lib/python3.10/site-packages/sklearn/metrics/cluster/_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and continuous values for target
#   warnings.warn(msg, UserWarning)
# /home/xj265/.local/lib/python3.10/site-packages/sklearn/metrics/cluster/_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and continuous values for target
#   warnings.warn(msg, UserWarning)
# /home/xj265/.local/lib/python3.10/site-packages/sklearn/metrics/cluster/_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and continuous values for target
#   warnings.warn(msg, UserWarning)
# /home/xj265/.local/lib/python3.10/site-packages/sklearn/metrics/cluster/_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and continuous values for target
#   warnings.warn(msg, UserWarning)
# /home/xj265/.local/lib/python3.10/site-packages/sklearn/metrics/cluster/_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and continuous values for target
#   warnings.warn(msg, UserWarning)
# /home/xj265/.local/lib/python3.10/site-packages/sklearn/metrics/cluster/_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and continuous values for target
#   warnings.warn(msg, UserWarning)
# /home/xj265/.local/lib/python3.10/site-packages/sklearn/metrics/cluster/_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and continuous values for target
#   warnings.warn(msg, UserWarning)
# /home/xj265/.local/lib/python3.10/site-packages/sklearn/metrics/cluster/_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and continuous values for target
#   warnings.warn(msg, UserWarning)
# /home/xj265/.local/lib/python3.10/site-packages/sklearn/metrics/cluster/_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and continuous values for target
#   warnings.warn(msg, UserWarning)
# /home/xj265/.local/lib/python3.10/site-packages/sklearn/metrics/cluster/_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and continuous values for target
#   warnings.warn(msg, UserWarning)
# /home/xj265/.local/lib/python3.10/site-packages/sklearn/metrics/cluster/_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and continuous values for target
#   warnings.warn(msg, UserWarning)
# /home/xj265/.local/lib/python3.10/site-packages/sklearn/metrics/cluster/_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and continuous values for target
#   warnings.warn(msg, UserWarning)
# /home/xj265/.local/lib/python3.10/site-packages/sklearn/metrics/cluster/_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and continuous values for target
#   warnings.warn(msg, UserWarning)
# /home/xj265/.local/lib/python3.10/site-packages/sklearn/metrics/cluster/_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and continuous values for target
#   warnings.warn(msg, UserWarning)
# /home/xj265/.local/lib/python3.10/site-packages/sklearn/metrics/cluster/_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and continuous values for target
#   warnings.warn(msg, UserWarning)
# /home/xj265/.local/lib/python3.10/site-packages/sklearn/metrics/cluster/_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and continuous values for target
#   warnings.warn(msg, UserWarning)
# /home/xj265/.local/lib/python3.10/site-packages/sklearn/metrics/cluster/_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and continuous values for target
#   warnings.warn(msg, UserWarning)
# /home/xj265/.local/lib/python3.10/site-packages/sklearn/metrics/cluster/_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and continuous values for target
#   warnings.warn(msg, UserWarning)
# /home/xj265/.local/lib/python3.10/site-packages/sklearn/metrics/cluster/_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and continuous values for target
#   warnings.warn(msg, UserWarning)
# /home/xj265/.local/lib/python3.10/site-packages/sklearn/metrics/cluster/_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and continuous values for target
#   warnings.warn(msg, UserWarning)
# /home/xj265/.local/lib/python3.10/site-packages/sklearn/metrics/cluster/_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and continuous values for target
#   warnings.warn(msg, UserWarning)
# /home/xj265/.local/lib/python3.10/site-packages/sklearn/metrics/cluster/_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and continuous values for target
#   warnings.warn(msg, UserWarning)
# /home/xj265/.local/lib/python3.10/site-packages/sklearn/metrics/cluster/_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and continuous values for target
#   warnings.warn(msg, UserWarning)
# /home/xj265/.local/lib/python3.10/site-packages/sklearn/metrics/cluster/_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and continuous values for target
#   warnings.warn(msg, UserWarning)
# /home/xj265/.local/lib/python3.10/site-packages/sklearn/metrics/cluster/_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and continuous values for target
#   warnings.warn(msg, UserWarning)
# /home/xj265/.local/lib/python3.10/site-packages/sklearn/metrics/cluster/_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and continuous values for target
#   warnings.warn(msg, UserWarning)
# /home/xj265/.local/lib/python3.10/site-packages/sklearn/metrics/cluster/_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and continuous values for target
#   warnings.warn(msg, UserWarning)
# /home/xj265/.local/lib/python3.10/site-packages/sklearn/metrics/cluster/_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and continuous values for target
#   warnings.warn(msg, UserWarning)
# /home/xj265/.local/lib/python3.10/site-packages/sklearn/metrics/cluster/_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and continuous values for target
#   warnings.warn(msg, UserWarning)
# /home/xj265/.local/lib/python3.10/site-packages/sklearn/metrics/cluster/_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and continuous values for target
#   warnings.warn(msg, UserWarning)
# /home/xj265/.local/lib/python3.10/site-packages/sklearn/metrics/cluster/_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and continuous values for target
#   warnings.warn(msg, UserWarning)
# /home/xj265/.local/lib/python3.10/site-packages/sklearn/metrics/cluster/_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and continuous values for target
#   warnings.warn(msg, UserWarning)
# /home/xj265/.local/lib/python3.10/site-packages/sklearn/metrics/cluster/_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and continuous values for target
#   warnings.warn(msg, UserWarning)
# /home/xj265/.local/lib/python3.10/site-packages/sklearn/metrics/cluster/_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and continuous values for target
#   warnings.warn(msg, UserWarning)
# /home/xj265/.local/lib/python3.10/site-packages/sklearn/metrics/cluster/_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and continuous values for target
#   warnings.warn(msg, UserWarning)
# /home/xj265/.local/lib/python3.10/site-packages/sklearn/metrics/cluster/_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and continuous values for target
#   warnings.warn(msg, UserWarning)
# /home/xj265/.local/lib/python3.10/site-packages/sklearn/metrics/cluster/_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and continuous values for target
#   warnings.warn(msg, UserWarning)
# /home/xj265/.local/lib/python3.10/site-packages/sklearn/metrics/cluster/_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and continuous values for target
#   warnings.warn(msg, UserWarning)
# /home/xj265/.local/lib/python3.10/site-packages/sklearn/metrics/cluster/_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and continuous values for target
#   warnings.warn(msg, UserWarning)
# /home/xj265/.local/lib/python3.10/site-packages/sklearn/metrics/cluster/_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and continuous values for target
#   warnings.warn(msg, UserWarning)
# /home/xj265/.local/lib/python3.10/site-packages/sklearn/metrics/cluster/_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and continuous values for target
#   warnings.warn(msg, UserWarning)
# /home/xj265/.local/lib/python3.10/site-packages/sklearn/metrics/cluster/_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and continuous values for target
#   warnings.warn(msg, UserWarning)
# /home/xj265/.local/lib/python3.10/site-packages/sklearn/metrics/cluster/_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and continuous values for target
#   warnings.warn(msg, UserWarning)
# /home/xj265/.local/lib/python3.10/site-packages/sklearn/metrics/cluster/_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and continuous values for target
#   warnings.warn(msg, UserWarning)
# /home/xj265/.local/lib/python3.10/site-packages/sklearn/metrics/cluster/_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and continuous values for target
#   warnings.warn(msg, UserWarning)
# /home/xj265/.local/lib/python3.10/site-packages/sklearn/metrics/cluster/_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and continuous values for target
#   warnings.warn(msg, UserWarning)
# /home/xj265/.local/lib/python3.10/site-packages/sklearn/metrics/cluster/_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and continuous values for target
#   warnings.warn(msg, UserWarning)
# /home/xj265/.local/lib/python3.10/site-packages/sklearn/metrics/cluster/_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and continuous values for target
#   warnings.warn(msg, UserWarning)
# /home/xj265/.local/lib/python3.10/site-packages/sklearn/metrics/cluster/_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and continuous values for target
#   warnings.warn(msg, UserWarning)
# /home/xj265/.local/lib/python3.10/site-packages/sklearn/metrics/cluster/_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and continuous values for target
#   warnings.warn(msg, UserWarning)
# /home/xj265/.local/lib/python3.10/site-packages/sklearn/metrics/cluster/_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and continuous values for target
#   warnings.warn(msg, UserWarning)
# /home/xj265/.local/lib/python3.10/site-packages/sklearn/metrics/cluster/_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and continuous values for target
#   warnings.warn(msg, UserWarning)
# /home/xj265/.local/lib/python3.10/site-packages/sklearn/metrics/cluster/_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and continuous values for target
#   warnings.warn(msg, UserWarning)
# /home/xj265/.local/lib/python3.10/site-packages/sklearn/metrics/cluster/_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and continuous values for target
#   warnings.warn(msg, UserWarning)
# /home/xj265/.local/lib/python3.10/site-packages/sklearn/metrics/cluster/_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and continuous values for target
#   warnings.warn(msg, UserWarning)
# /home/xj265/.local/lib/python3.10/site-packages/sklearn/metrics/cluster/_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and continuous values for target
#   warnings.warn(msg, UserWarning)
# /home/xj265/.local/lib/python3.10/site-packages/sklearn/metrics/cluster/_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and continuous values for target
#   warnings.warn(msg, UserWarning)
# /home/xj265/.local/lib/python3.10/site-packages/sklearn/metrics/cluster/_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and continuous values for target
#   warnings.warn(msg, UserWarning)
# /home/xj265/.local/lib/python3.10/site-packages/sklearn/metrics/cluster/_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and continuous values for target
#   warnings.warn(msg, UserWarning)
# /home/xj265/.local/lib/python3.10/site-packages/sklearn/metrics/cluster/_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and continuous values for target
#   warnings.warn(msg, UserWarning)
# /home/xj265/.local/lib/python3.10/site-packages/sklearn/metrics/cluster/_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and continuous values for target
#   warnings.warn(msg, UserWarning)
# /home/xj265/.local/lib/python3.10/site-packages/sklearn/metrics/cluster/_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and continuous values for target
#   warnings.warn(msg, UserWarning)
# /home/xj265/.local/lib/python3.10/site-packages/sklearn/metrics/cluster/_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and continuous values for target
#   warnings.warn(msg, UserWarning)
# /home/xj265/.local/lib/python3.10/site-packages/sklearn/metrics/cluster/_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and continuous values for target
#   warnings.warn(msg, UserWarning)
# /home/xj265/.local/lib/python3.10/site-packages/sklearn/metrics/cluster/_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and continuous values for target
#   warnings.warn(msg, UserWarning)
# /home/xj265/.local/lib/python3.10/site-packages/sklearn/metrics/cluster/_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and continuous values for target
#   warnings.warn(msg, UserWarning)
# /home/xj265/.local/lib/python3.10/site-packages/sklearn/metrics/cluster/_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and continuous values for target
#   warnings.warn(msg, UserWarning)
# /home/xj265/.local/lib/python3.10/site-packages/sklearn/metrics/cluster/_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and continuous values for target
#   warnings.warn(msg, UserWarning)
# /home/xj265/.local/lib/python3.10/site-packages/sklearn/metrics/cluster/_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and continuous values for target
#   warnings.warn(msg, UserWarning)
# /home/xj265/.local/lib/python3.10/site-packages/sklearn/metrics/cluster/_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and continuous values for target
#   warnings.warn(msg, UserWarning)
# /home/xj265/.local/lib/python3.10/site-packages/sklearn/metrics/cluster/_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and continuous values for target
#   warnings.warn(msg, UserWarning)
# /home/xj265/.local/lib/python3.10/site-packages/sklearn/metrics/cluster/_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and continuous values for target
#   warnings.warn(msg, UserWarning)
# /home/xj265/.local/lib/python3.10/site-packages/sklearn/metrics/cluster/_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and continuous values for target
#   warnings.warn(msg, UserWarning)
# /home/xj265/.local/lib/python3.10/site-packages/sklearn/metrics/cluster/_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and continuous values for target
#   warnings.warn(msg, UserWarning)
# /home/xj265/.local/lib/python3.10/site-packages/sklearn/metrics/cluster/_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and continuous values for target
#   warnings.warn(msg, UserWarning)
# /home/xj265/.local/lib/python3.10/site-packages/sklearn/metrics/cluster/_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and continuous values for target
#   warnings.warn(msg, UserWarning)
# /home/xj265/.local/lib/python3.10/site-packages/sklearn/metrics/cluster/_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and continuous values for target
#   warnings.warn(msg, UserWarning)
# /home/xj265/.local/lib/python3.10/site-packages/sklearn/metrics/cluster/_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and continuous values for target
#   warnings.warn(msg, UserWarning)
# /home/xj265/.local/lib/python3.10/site-packages/sklearn/metrics/cluster/_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and continuous values for target
#   warnings.warn(msg, UserWarning)
# /home/xj265/.local/lib/python3.10/site-packages/sklearn/metrics/cluster/_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and continuous values for target
#   warnings.warn(msg, UserWarning)
# /home/xj265/.local/lib/python3.10/site-packages/sklearn/metrics/cluster/_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and continuous values for target
#   warnings.warn(msg, UserWarning)
# /home/xj265/.local/lib/python3.10/site-packages/sklearn/metrics/cluster/_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and continuous values for target
#   warnings.warn(msg, UserWarning)
# /home/xj265/.local/lib/python3.10/site-packages/sklearn/metrics/cluster/_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and continuous values for target
#   warnings.warn(msg, UserWarning)
# /home/xj265/.local/lib/python3.10/site-packages/sklearn/metrics/cluster/_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and continuous values for target
#   warnings.warn(msg, UserWarning)
# /home/xj265/.local/lib/python3.10/site-packages/sklearn/metrics/cluster/_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and continuous values for target
#   warnings.warn(msg, UserWarning)
# /home/xj265/.local/lib/python3.10/site-packages/sklearn/metrics/cluster/_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and continuous values for target
#   warnings.warn(msg, UserWarning)
# /home/xj265/.local/lib/python3.10/site-packages/sklearn/metrics/cluster/_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and continuous values for target
#   warnings.warn(msg, UserWarning)
# /home/xj265/.local/lib/python3.10/site-packages/sklearn/metrics/cluster/_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and continuous values for target
#   warnings.warn(msg, UserWarning)
# /home/xj265/.local/lib/python3.10/site-packages/sklearn/metrics/cluster/_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and continuous values for target
#   warnings.warn(msg, UserWarning)
# /home/xj265/.local/lib/python3.10/site-packages/sklearn/metrics/cluster/_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and continuous values for target
#   warnings.warn(msg, UserWarning)
# /home/xj265/.local/lib/python3.10/site-packages/sklearn/metrics/cluster/_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and continuous values for target
#   warnings.warn(msg, UserWarning)
# /home/xj265/.local/lib/python3.10/site-packages/sklearn/metrics/cluster/_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and continuous values for target
#   warnings.warn(msg, UserWarning)
# /home/xj265/.local/lib/python3.10/site-packages/sklearn/metrics/cluster/_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and continuous values for target
#   warnings.warn(msg, UserWarning)
# /home/xj265/.local/lib/python3.10/site-packages/sklearn/metrics/cluster/_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and continuous values for target
#   warnings.warn(msg, UserWarning)
# /home/xj265/.local/lib/python3.10/site-packages/sklearn/metrics/cluster/_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and continuous values for target
#   warnings.warn(msg, UserWarning)
# /home/xj265/.local/lib/python3.10/site-packages/sklearn/metrics/cluster/_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and continuous values for target
#   warnings.warn(msg, UserWarning)
# /home/xj265/.local/lib/python3.10/site-packages/sklearn/metrics/cluster/_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and continuous values for target
#   warnings.warn(msg, UserWarning)
# /home/xj265/.local/lib/python3.10/site-packages/sklearn/metrics/cluster/_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and continuous values for target
#   warnings.warn(msg, UserWarning)
# /home/xj265/.local/lib/python3.10/site-packages/sklearn/metrics/cluster/_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and continuous values for target
#   warnings.warn(msg, UserWarning)
# /home/xj265/.local/lib/python3.10/site-packages/sklearn/metrics/cluster/_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and continuous values for target
#   warnings.warn(msg, UserWarning)
# /home/xj265/.local/lib/python3.10/site-packages/sklearn/metrics/cluster/_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and continuous values for target
#   warnings.warn(msg, UserWarning)
# /home/xj265/.local/lib/python3.10/site-packages/sklearn/metrics/cluster/_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and continuous values for target
#   warnings.warn(msg, UserWarning)
# /home/xj265/.local/lib/python3.10/site-packages/sklearn/metrics/cluster/_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and continuous values for target
#   warnings.warn(msg, UserWarning)
# /home/xj265/.local/lib/python3.10/site-packages/sklearn/metrics/cluster/_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and continuous values for target
#   warnings.warn(msg, UserWarning)
# /home/xj265/.local/lib/python3.10/site-packages/sklearn/metrics/cluster/_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and continuous values for target
#   warnings.warn(msg, UserWarning)
# /home/xj265/.local/lib/python3.10/site-packages/sklearn/metrics/cluster/_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and continuous values for target
#   warnings.warn(msg, UserWarning)
# /home/xj265/.local/lib/python3.10/site-packages/sklearn/metrics/cluster/_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and continuous values for target
#   warnings.warn(msg, UserWarning)
# /home/xj265/.local/lib/python3.10/site-packages/sklearn/metrics/cluster/_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and continuous values for target
#   warnings.warn(msg, UserWarning)
# /home/xj265/.local/lib/python3.10/site-packages/sklearn/metrics/cluster/_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and continuous values for target
#   warnings.warn(msg, UserWarning)
# /home/xj265/.local/lib/python3.10/site-packages/sklearn/metrics/cluster/_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and continuous values for target
#   warnings.warn(msg, UserWarning)
# /home/xj265/.local/lib/python3.10/site-packages/sklearn/metrics/cluster/_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and continuous values for target
#   warnings.warn(msg, UserWarning)
# /home/xj265/.local/lib/python3.10/site-packages/sklearn/metrics/cluster/_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and continuous values for target
#   warnings.warn(msg, UserWarning)
# /home/xj265/.local/lib/python3.10/site-packages/sklearn/metrics/cluster/_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and continuous values for target
#   warnings.warn(msg, UserWarning)
# /home/xj265/.local/lib/python3.10/site-packages/sklearn/metrics/cluster/_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and continuous values for target
#   warnings.warn(msg, UserWarning)
# /home/xj265/.local/lib/python3.10/site-packages/sklearn/metrics/cluster/_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and continuous values for target
#   warnings.warn(msg, UserWarning)
# /home/xj265/.local/lib/python3.10/site-packages/sklearn/metrics/cluster/_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and continuous values for target
#   warnings.warn(msg, UserWarning)
# /home/xj265/.local/lib/python3.10/site-packages/sklearn/metrics/cluster/_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and continuous values for target
#   warnings.warn(msg, UserWarning)
# /home/xj265/.local/lib/python3.10/site-packages/sklearn/metrics/cluster/_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and continuous values for target
#   warnings.warn(msg, UserWarning)
# /home/xj265/.local/lib/python3.10/site-packages/sklearn/metrics/cluster/_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and continuous values for target
#   warnings.warn(msg, UserWarning)
# /home/xj265/.local/lib/python3.10/site-packages/sklearn/metrics/cluster/_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and continuous values for target
#   warnings.warn(msg, UserWarning)
# /home/xj265/.local/lib/python3.10/site-packages/sklearn/metrics/cluster/_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and continuous values for target
#   warnings.warn(msg, UserWarning)
# /home/xj265/.local/lib/python3.10/site-packages/sklearn/metrics/cluster/_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and continuous values for target
#   warnings.warn(msg, UserWarning)
# /home/xj265/.local/lib/python3.10/site-packages/sklearn/metrics/cluster/_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and continuous values for target
#   warnings.warn(msg, UserWarning)
# /home/xj265/.local/lib/python3.10/site-packages/sklearn/metrics/cluster/_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and continuous values for target
#   warnings.warn(msg, UserWarning)
# /home/xj265/.local/lib/python3.10/site-packages/sklearn/metrics/cluster/_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and continuous values for target
#   warnings.warn(msg, UserWarning)
# /home/xj265/.local/lib/python3.10/site-packages/sklearn/metrics/cluster/_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and continuous values for target
#   warnings.warn(msg, UserWarning)
# /home/xj265/.local/lib/python3.10/site-packages/sklearn/metrics/cluster/_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and continuous values for target
#   warnings.warn(msg, UserWarning)
# /home/xj265/.local/lib/python3.10/site-packages/sklearn/metrics/cluster/_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and continuous values for target
#   warnings.warn(msg, UserWarning)
# /home/xj265/.local/lib/python3.10/site-packages/sklearn/metrics/cluster/_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and continuous values for target
#   warnings.warn(msg, UserWarning)
# /home/xj265/.local/lib/python3.10/site-packages/sklearn/metrics/cluster/_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and continuous values for target
#   warnings.warn(msg, UserWarning)
# /home/xj265/.local/lib/python3.10/site-packages/sklearn/metrics/cluster/_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and continuous values for target
#   warnings.warn(msg, UserWarning)
# /home/xj265/.local/lib/python3.10/site-packages/sklearn/metrics/cluster/_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and continuous values for target
#   warnings.warn(msg, UserWarning)
# /home/xj265/.local/lib/python3.10/site-packages/sklearn/metrics/cluster/_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and continuous values for target
#   warnings.warn(msg, UserWarning)
# /home/xj265/.local/lib/python3.10/site-packages/sklearn/metrics/cluster/_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and continuous values for target
#   warnings.warn(msg, UserWarning)
# /home/xj265/.local/lib/python3.10/site-packages/sklearn/metrics/cluster/_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and continuous values for target
#   warnings.warn(msg, UserWarning)
# /home/xj265/.local/lib/python3.10/site-packages/sklearn/metrics/cluster/_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and continuous values for target
#   warnings.warn(msg, UserWarning)
# /home/xj265/.local/lib/python3.10/site-packages/sklearn/metrics/cluster/_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and continuous values for target
#   warnings.warn(msg, UserWarning)
# /home/xj265/.local/lib/python3.10/site-packages/sklearn/metrics/cluster/_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and continuous values for target
#   warnings.warn(msg, UserWarning)
# /home/xj265/.local/lib/python3.10/site-packages/sklearn/metrics/cluster/_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and continuous values for target
#   warnings.warn(msg, UserWarning)
# /home/xj265/.local/lib/python3.10/site-packages/sklearn/metrics/cluster/_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and continuous values for target
#   warnings.warn(msg, UserWarning)
# /home/xj265/.local/lib/python3.10/site-packages/sklearn/metrics/cluster/_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and continuous values for target
#   warnings.warn(msg, UserWarning)
# /home/xj265/.local/lib/python3.10/site-packages/sklearn/metrics/cluster/_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and continuous values for target
#   warnings.warn(msg, UserWarning)
# /home/xj265/.local/lib/python3.10/site-packages/sklearn/metrics/cluster/_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and continuous values for target
#   warnings.warn(msg, UserWarning)
# /home/xj265/.local/lib/python3.10/site-packages/sklearn/metrics/cluster/_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and continuous values for target
#   warnings.warn(msg, UserWarning)
# /home/xj265/.local/lib/python3.10/site-packages/sklearn/metrics/cluster/_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and continuous values for target
#   warnings.warn(msg, UserWarning)
# /home/xj265/.local/lib/python3.10/site-packages/sklearn/metrics/cluster/_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and continuous values for target
#   warnings.warn(msg, UserWarning)
# /home/xj265/.local/lib/python3.10/site-packages/sklearn/metrics/cluster/_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and continuous values for target
#   warnings.warn(msg, UserWarning)
# /home/xj265/.local/lib/python3.10/site-packages/sklearn/metrics/cluster/_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and continuous values for target
#   warnings.warn(msg, UserWarning)
# /home/xj265/.local/lib/python3.10/site-packages/sklearn/metrics/cluster/_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and continuous values for target
#   warnings.warn(msg, UserWarning)
# /home/xj265/.local/lib/python3.10/site-packages/sklearn/metrics/cluster/_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and continuous values for target
#   warnings.warn(msg, UserWarning)
# /home/xj265/.local/lib/python3.10/site-packages/sklearn/metrics/cluster/_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and continuous values for target
#   warnings.warn(msg, UserWarning)
# /home/xj265/.local/lib/python3.10/site-packages/sklearn/metrics/cluster/_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and continuous values for target
#   warnings.warn(msg, UserWarning)
# /home/xj265/.local/lib/python3.10/site-packages/sklearn/metrics/cluster/_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and continuous values for target
#   warnings.warn(msg, UserWarning)
# /home/xj265/.local/lib/python3.10/site-packages/sklearn/metrics/cluster/_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and continuous values for target
#   warnings.warn(msg, UserWarning)
# /home/xj265/.local/lib/python3.10/site-packages/sklearn/metrics/cluster/_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and continuous values for target
#   warnings.warn(msg, UserWarning)
# /home/xj265/.local/lib/python3.10/site-packages/sklearn/metrics/cluster/_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and continuous values for target
#   warnings.warn(msg, UserWarning)
# /home/xj265/.local/lib/python3.10/site-packages/sklearn/metrics/cluster/_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and continuous values for target
#   warnings.warn(msg, UserWarning)
# ...
#   warnings.warn(msg, UserWarning)
# /home/xj265/.local/lib/python3.10/site-packages/sklearn/metrics/cluster/_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and continuous values for target
#   warnings.warn(msg, UserWarning)
# /home/xj265/.local/lib/python3.10/site-packages/sklearn/metrics/cluster/_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and continuous values for target
#   warnings.warn(msg, UserWarning)
# /home/xj265/.local/lib/python3.10/site-packages/sklearn/metrics/cluster/_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and continuous values for target
#   warnings.warn(msg, UserWarning)
# /home/xj265/.local/lib/python3.10/site-packages/sklearn/metrics/cluster/_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and continuous values for target
#   warnings.warn(msg, UserWarning)
# /home/xj265/.local/lib/python3.10/site-packages/sklearn/metrics/cluster/_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and continuous values for target
#   warnings.warn(msg, UserWarning)
# /home/xj265/.local/lib/python3.10/site-packages/sklearn/metrics/cluster/_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and continuous values for target
#   warnings.warn(msg, UserWarning)
# /home/xj265/.local/lib/python3.10/site-packages/sklearn/metrics/cluster/_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and continuous values for target
#   warnings.warn(msg, UserWarning)
# /home/xj265/.local/lib/python3.10/site-packages/sklearn/metrics/cluster/_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and continuous values for target
#   warnings.warn(msg, UserWarning)
# /home/xj265/.local/lib/python3.10/site-packages/sklearn/metrics/cluster/_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and continuous values for target
#   warnings.warn(msg, UserWarning)
# /home/xj265/.local/lib/python3.10/site-packages/sklearn/metrics/cluster/_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and continuous values for target
#   warnings.warn(msg, UserWarning)
# /home/xj265/.local/lib/python3.10/site-packages/sklearn/metrics/cluster/_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and continuous values for target
#   warnings.warn(msg, UserWarning)
# /home/xj265/.local/lib/python3.10/site-packages/sklearn/metrics/cluster/_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and continuous values for target
#   warnings.warn(msg, UserWarning)
# /home/xj265/.local/lib/python3.10/site-packages/sklearn/metrics/cluster/_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and continuous values for target
#   warnings.warn(msg, UserWarning)
# /home/xj265/.local/lib/python3.10/site-packages/sklearn/metrics/cluster/_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and continuous values for target
#   warnings.warn(msg, UserWarning)
# /home/xj265/.local/lib/python3.10/site-packages/sklearn/metrics/cluster/_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and continuous values for target
#   warnings.warn(msg, UserWarning)
# /home/xj265/.local/lib/python3.10/site-packages/sklearn/metrics/cluster/_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and continuous values for target
#   warnings.warn(msg, UserWarning)
# /home/xj265/.local/lib/python3.10/site-packages/sklearn/metrics/cluster/_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and continuous values for target
#   warnings.warn(msg, UserWarning)
# /home/xj265/.local/lib/python3.10/site-packages/sklearn/metrics/cluster/_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and continuous values for target
#   warnings.warn(msg, UserWarning)
# /home/xj265/.local/lib/python3.10/site-packages/sklearn/metrics/cluster/_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and continuous values for target
#   warnings.warn(msg, UserWarning)
# /home/xj265/.local/lib/python3.10/site-packages/sklearn/metrics/cluster/_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and continuous values for target
#   warnings.warn(msg, UserWarning)
# /home/xj265/.local/lib/python3.10/site-packages/sklearn/metrics/cluster/_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and continuous values for target
#   warnings.warn(msg, UserWarning)
# /home/xj265/.local/lib/python3.10/site-packages/sklearn/metrics/cluster/_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and continuous values for target
#   warnings.warn(msg, UserWarning)
# /home/xj265/.local/lib/python3.10/site-packages/sklearn/metrics/cluster/_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and continuous values for target
#   warnings.warn(msg, UserWarning)
# /home/xj265/.local/lib/python3.10/site-packages/sklearn/metrics/cluster/_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and continuous values for target
#   warnings.warn(msg, UserWarning)
# /home/xj265/.local/lib/python3.10/site-packages/sklearn/metrics/cluster/_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and continuous values for target
#   warnings.warn(msg, UserWarning)
# /home/xj265/.local/lib/python3.10/site-packages/sklearn/metrics/cluster/_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and continuous values for target
#   warnings.warn(msg, UserWarning)
# /home/xj265/.local/lib/python3.10/site-packages/sklearn/metrics/cluster/_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and continuous values for target
#   warnings.warn(msg, UserWarning)
# /home/xj265/.local/lib/python3.10/site-packages/sklearn/metrics/cluster/_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and continuous values for target
#   warnings.warn(msg, UserWarning)
# /home/xj265/.local/lib/python3.10/site-packages/sklearn/metrics/cluster/_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and continuous values for target
#   warnings.warn(msg, UserWarning)
# /home/xj265/.local/lib/python3.10/site-packages/sklearn/metrics/cluster/_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and continuous values for target
#   warnings.warn(msg, UserWarning)
# /home/xj265/.local/lib/python3.10/site-packages/sklearn/metrics/cluster/_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and continuous values for target
#   warnings.warn(msg, UserWarning)
# /home/xj265/.local/lib/python3.10/site-packages/sklearn/metrics/cluster/_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and continuous values for target
#   warnings.warn(msg, UserWarning)
# /home/xj265/.local/lib/python3.10/site-packages/sklearn/metrics/cluster/_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and continuous values for target
#   warnings.warn(msg, UserWarning)
# /home/xj265/.local/lib/python3.10/site-packages/sklearn/metrics/cluster/_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and continuous values for target
#   warnings.warn(msg, UserWarning)
# /home/xj265/.local/lib/python3.10/site-packages/sklearn/metrics/cluster/_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and continuous values for target
#   warnings.warn(msg, UserWarning)
# /home/xj265/.local/lib/python3.10/site-packages/sklearn/metrics/cluster/_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and continuous values for target
#   warnings.warn(msg, UserWarning)
# /home/xj265/.local/lib/python3.10/site-packages/sklearn/metrics/cluster/_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and continuous values for target
#   warnings.warn(msg, UserWarning)
# /home/xj265/.local/lib/python3.10/site-packages/sklearn/metrics/cluster/_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and continuous values for target
#   warnings.warn(msg, UserWarning)
# /home/xj265/.local/lib/python3.10/site-packages/sklearn/metrics/cluster/_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and continuous values for target
#   warnings.warn(msg, UserWarning)
# /home/xj265/.local/lib/python3.10/site-packages/sklearn/metrics/cluster/_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and continuous values for target
#   warnings.warn(msg, UserWarning)
# /home/xj265/.local/lib/python3.10/site-packages/sklearn/metrics/cluster/_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and continuous values for target
#   warnings.warn(msg, UserWarning)
# /home/xj265/.local/lib/python3.10/site-packages/sklearn/metrics/cluster/_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and continuous values for target
#   warnings.warn(msg, UserWarning)
# /home/xj265/.local/lib/python3.10/site-packages/sklearn/metrics/cluster/_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and continuous values for target
#   warnings.warn(msg, UserWarning)
# /home/xj265/.local/lib/python3.10/site-packages/sklearn/metrics/cluster/_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and continuous values for target
#   warnings.warn(msg, UserWarning)
# /home/xj265/.local/lib/python3.10/site-packages/sklearn/metrics/cluster/_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and continuous values for target
#   warnings.warn(msg, UserWarning)
# /home/xj265/.local/lib/python3.10/site-packages/sklearn/metrics/cluster/_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and continuous values for target
#   warnings.warn(msg, UserWarning)
# /home/xj265/.local/lib/python3.10/site-packages/sklearn/metrics/cluster/_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and continuous values for target
#   warnings.warn(msg, UserWarning)
# /home/xj265/.local/lib/python3.10/site-packages/sklearn/metrics/cluster/_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and continuous values for target
#   warnings.warn(msg, UserWarning)
# /home/xj265/.local/lib/python3.10/site-packages/sklearn/metrics/cluster/_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and continuous values for target
#   warnings.warn(msg, UserWarning)
# /home/xj265/.local/lib/python3.10/site-packages/sklearn/metrics/cluster/_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and continuous values for target
#   warnings.warn(msg, UserWarning)
# /home/xj265/.local/lib/python3.10/site-packages/sklearn/metrics/cluster/_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and continuous values for target
#   warnings.warn(msg, UserWarning)
# /home/xj265/.local/lib/python3.10/site-packages/sklearn/metrics/cluster/_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and continuous values for target
#   warnings.warn(msg, UserWarning)
# /home/xj265/.local/lib/python3.10/site-packages/sklearn/metrics/cluster/_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and continuous values for target
#   warnings.warn(msg, UserWarning)
# /home/xj265/.local/lib/python3.10/site-packages/sklearn/metrics/cluster/_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and continuous values for target
#   warnings.warn(msg, UserWarning)
# /home/xj265/.local/lib/python3.10/site-packages/sklearn/metrics/cluster/_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and continuous values for target
#   warnings.warn(msg, UserWarning)
# /home/xj265/.local/lib/python3.10/site-packages/sklearn/metrics/cluster/_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and continuous values for target
#   warnings.warn(msg, UserWarning)
# /home/xj265/.local/lib/python3.10/site-packages/sklearn/metrics/cluster/_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and continuous values for target
#   warnings.warn(msg, UserWarning)
# /home/xj265/.local/lib/python3.10/site-packages/sklearn/metrics/cluster/_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and continuous values for target
#   warnings.warn(msg, UserWarning)
# /home/xj265/.local/lib/python3.10/site-packages/sklearn/metrics/cluster/_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and continuous values for target
#   warnings.warn(msg, UserWarning)
# /home/xj265/.local/lib/python3.10/site-packages/sklearn/metrics/cluster/_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and continuous values for target
#   warnings.warn(msg, UserWarning)
# /home/xj265/.local/lib/python3.10/site-packages/sklearn/metrics/cluster/_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and continuous values for target
#   warnings.warn(msg, UserWarning)
# /home/xj265/.local/lib/python3.10/site-packages/sklearn/metrics/cluster/_supervised.py:66: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and continuous values for target
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# ## Hill-Climb Search

# %%
from pgmpy.estimators import HillClimbSearch

est = HillClimbSearch(df)
model = est.estimate()
model.to_graphviz().draw('adult_hill.png', prog='dot')
# Out:
#   0%|          | 0/1000000 [00:00<?, ?it/s]
# /home/xj265/.local/lib/python3.10/site-packages/pgmpy/estimators/StructureScore.py:136: RuntimeWarning: overflow encountered in scalar multiply
#   (num_parents_states - counts.shape[1]) * var_cardinality * gammaln(1)
# /home/xj265/.local/lib/python3.10/site-packages/pgmpy/estimators/StructureScore.py:136: RuntimeWarning: overflow encountered in scalar multiply
#   (num_parents_states - counts.shape[1]) * var_cardinality * gammaln(1)
# /home/xj265/.local/lib/python3.10/site-packages/pgmpy/estimators/StructureScore.py:136: RuntimeWarning: overflow encountered in scalar multiply
#   (num_parents_states - counts.shape[1]) * var_cardinality * gammaln(1)
# /home/xj265/.local/lib/python3.10/site-packages/pgmpy/estimators/StructureScore.py:136: RuntimeWarning: overflow encountered in scalar multiply
#   (num_parents_states - counts.shape[1]) * var_cardinality * gammaln(1)
# /home/xj265/.local/lib/python3.10/site-packages/pgmpy/estimators/StructureScore.py:136: RuntimeWarning: overflow encountered in scalar multiply
#   (num_parents_states - counts.shape[1]) * var_cardinality * gammaln(1)
# /home/xj265/.local/lib/python3.10/site-packages/pgmpy/estimators/StructureScore.py:136: RuntimeWarning: overflow encountered in scalar multiply
#   (num_parents_states - counts.shape[1]) * var_cardinality * gammaln(1)
# /home/xj265/.local/lib/python3.10/site-packages/pgmpy/estimators/StructureScore.py:136: RuntimeWarning: overflow encountered in scalar multiply
#   (num_parents_states - counts.shape[1]) * var_cardinality * gammaln(1)
# /home/xj265/.local/lib/python3.10/site-packages/pgmpy/estimators/StructureScore.py:136: RuntimeWarning: overflow encountered in scalar multiply
#   (num_parents_states - counts.shape[1]) * var_cardinality * gammaln(1)
# /home/xj265/.local/lib/python3.10/site-packages/pgmpy/estimators/StructureScore.py:136: RuntimeWarning: overflow encountered in scalar multiply
#   (num_parents_states - counts.shape[1]) * var_cardinality * gammaln(1)
# /home/xj265/.local/lib/python3.10/site-packages/pgmpy/estimators/StructureScore.py:136: RuntimeWarning: overflow encountered in scalar multiply
#   (num_parents_states - counts.shape[1]) * var_cardinality * gammaln(1)
# /home/xj265/.local/lib/python3.10/site-packages/pgmpy/estimators/StructureScore.py:136: RuntimeWarning: overflow encountered in scalar multiply
#   (num_parents_states - counts.shape[1]) * var_cardinality * gammaln(1)
# /home/xj265/.local/lib/python3.10/site-packages/pgmpy/estimators/StructureScore.py:136: RuntimeWarning: overflow encountered in scalar multiply
#   (num_parents_states - counts.shape[1]) * var_cardinality * gammaln(1)
# /home/xj265/.local/lib/python3.10/site-packages/pgmpy/estimators/StructureScore.py:136: RuntimeWarning: overflow encountered in scalar multiply
#   (num_parents_states - counts.shape[1]) * var_cardinality * gammaln(1)
# /home/xj265/.local/lib/python3.10/site-packages/pgmpy/estimators/StructureScore.py:136: RuntimeWarning: overflow encountered in scalar multiply
#   (num_parents_states - counts.shape[1]) * var_cardinality * gammaln(1)
# /home/xj265/.local/lib/python3.10/site-packages/pgmpy/estimators/StructureScore.py:136: RuntimeWarning: overflow encountered in scalar multiply
#   (num_parents_states - counts.shape[1]) * var_cardinality * gammaln(1)
# /home/xj265/.local/lib/python3.10/site-packages/pgmpy/estimators/StructureScore.py:136: RuntimeWarning: overflow encountered in scalar multiply
#   (num_parents_states - counts.shape[1]) * var_cardinality * gammaln(1)
# /home/xj265/.local/lib/python3.10/site-packages/pgmpy/estimators/StructureScore.py:136: RuntimeWarning: overflow encountered in scalar multiply
#   (num_parents_states - counts.shape[1]) * var_cardinality * gammaln(1)
# /home/xj265/.local/lib/python3.10/site-packages/pgmpy/estimators/StructureScore.py:136: RuntimeWarning: overflow encountered in scalar multiply
#   (num_parents_states - counts.shape[1]) * var_cardinality * gammaln(1)
# /home/xj265/.local/lib/python3.10/site-packages/pgmpy/estimators/StructureScore.py:136: RuntimeWarning: overflow encountered in scalar multiply
#   (num_parents_states - counts.shape[1]) * var_cardinality * gammaln(1)
# /home/xj265/.local/lib/python3.10/site-packages/pgmpy/estimators/StructureScore.py:136: RuntimeWarning: overflow encountered in scalar multiply
#   (num_parents_states - counts.shape[1]) * var_cardinality * gammaln(1)
# /home/xj265/.local/lib/python3.10/site-packages/pgmpy/estimators/StructureScore.py:136: RuntimeWarning: overflow encountered in scalar multiply
#   (num_parents_states - counts.shape[1]) * var_cardinality * gammaln(1)
# /home/xj265/.local/lib/python3.10/site-packages/pgmpy/estimators/StructureScore.py:136: RuntimeWarning: overflow encountered in scalar multiply
#   (num_parents_states - counts.shape[1]) * var_cardinality * gammaln(1)
# /home/xj265/.local/lib/python3.10/site-packages/pgmpy/estimators/StructureScore.py:136: RuntimeWarning: overflow encountered in scalar multiply
#   (num_parents_states - counts.shape[1]) * var_cardinality * gammaln(1)
# /home/xj265/.local/lib/python3.10/site-packages/pgmpy/estimators/StructureScore.py:136: RuntimeWarning: overflow encountered in scalar multiply
#   (num_parents_states - counts.shape[1]) * var_cardinality * gammaln(1)
# /home/xj265/.local/lib/python3.10/site-packages/pgmpy/estimators/StructureScore.py:136: RuntimeWarning: overflow encountered in scalar multiply
#   (num_parents_states - counts.shape[1]) * var_cardinality * gammaln(1)
# /home/xj265/.local/lib/python3.10/site-packages/pgmpy/estimators/StructureScore.py:136: RuntimeWarning: overflow encountered in scalar multiply
#   (num_parents_states - counts.shape[1]) * var_cardinality * gammaln(1)
# /home/xj265/.local/lib/python3.10/site-packages/pgmpy/estimators/StructureScore.py:136: RuntimeWarning: overflow encountered in scalar multiply
#   (num_parents_states - counts.shape[1]) * var_cardinality * gammaln(1)
# /home/xj265/.local/lib/python3.10/site-packages/pgmpy/estimators/StructureScore.py:136: RuntimeWarning: overflow encountered in scalar multiply
#   (num_parents_states - counts.shape[1]) * var_cardinality * gammaln(1)
# /home/xj265/.local/lib/python3.10/site-packages/pgmpy/estimators/StructureScore.py:136: RuntimeWarning: overflow encountered in scalar multiply
#   (num_parents_states - counts.shape[1]) * var_cardinality * gammaln(1)
# /home/xj265/.local/lib/python3.10/site-packages/pgmpy/estimators/StructureScore.py:136: RuntimeWarning: overflow encountered in scalar multiply
#   (num_parents_states - counts.shape[1]) * var_cardinality * gammaln(1)
# /home/xj265/.local/lib/python3.10/site-packages/pgmpy/estimators/StructureScore.py:136: RuntimeWarning: overflow encountered in scalar multiply
#   (num_parents_states - counts.shape[1]) * var_cardinality * gammaln(1)
# /home/xj265/.local/lib/python3.10/site-packages/pgmpy/estimators/StructureScore.py:136: RuntimeWarning: overflow encountered in scalar multiply
#   (num_parents_states - counts.shape[1]) * var_cardinality * gammaln(1)
# /home/xj265/.local/lib/python3.10/site-packages/pgmpy/estimators/StructureScore.py:136: RuntimeWarning: overflow encountered in scalar multiply
#   (num_parents_states - counts.shape[1]) * var_cardinality * gammaln(1)
# /home/xj265/.local/lib/python3.10/site-packages/pgmpy/estimators/StructureScore.py:136: RuntimeWarning: overflow encountered in scalar multiply
#   (num_parents_states - counts.shape[1]) * var_cardinality * gammaln(1)
# /home/xj265/.local/lib/python3.10/site-packages/pgmpy/estimators/StructureScore.py:136: RuntimeWarning: overflow encountered in scalar multiply
#   (num_parents_states - counts.shape[1]) * var_cardinality * gammaln(1)
# /home/xj265/.local/lib/python3.10/site-packages/pgmpy/estimators/StructureScore.py:136: RuntimeWarning: overflow encountered in scalar multiply
#   (num_parents_states - counts.shape[1]) * var_cardinality * gammaln(1)
# /home/xj265/.local/lib/python3.10/site-packages/pgmpy/estimators/StructureScore.py:136: RuntimeWarning: overflow encountered in scalar multiply
#   (num_parents_states - counts.shape[1]) * var_cardinality * gammaln(1)
# /home/xj265/.local/lib/python3.10/site-packages/pgmpy/estimators/StructureScore.py:136: RuntimeWarning: overflow encountered in scalar multiply
#   (num_parents_states - counts.shape[1]) * var_cardinality * gammaln(1)
# /home/xj265/.local/lib/python3.10/site-packages/pgmpy/estimators/StructureScore.py:136: RuntimeWarning: overflow encountered in scalar multiply
#   (num_parents_states - counts.shape[1]) * var_cardinality * gammaln(1)
# /home/xj265/.local/lib/python3.10/site-packages/pgmpy/estimators/StructureScore.py:136: RuntimeWarning: overflow encountered in scalar multiply
#   (num_parents_states - counts.shape[1]) * var_cardinality * gammaln(1)
# /home/xj265/.local/lib/python3.10/site-packages/pgmpy/estimators/StructureScore.py:136: RuntimeWarning: overflow encountered in scalar multiply
#   (num_parents_states - counts.shape[1]) * var_cardinality * gammaln(1)
# /home/xj265/.local/lib/python3.10/site-packages/pgmpy/estimators/StructureScore.py:136: RuntimeWarning: overflow encountered in scalar multiply
#   (num_parents_states - counts.shape[1]) * var_cardinality * gammaln(1)
# /home/xj265/.local/lib/python3.10/site-packages/pgmpy/estimators/StructureScore.py:136: RuntimeWarning: overflow encountered in scalar multiply
#   (num_parents_states - counts.shape[1]) * var_cardinality * gammaln(1)
# /home/xj265/.local/lib/python3.10/site-packages/pgmpy/estimators/StructureScore.py:136: RuntimeWarning: overflow encountered in scalar multiply
#   (num_parents_states - counts.shape[1]) * var_cardinality * gammaln(1)
# /home/xj265/.local/lib/python3.10/site-packages/pgmpy/estimators/StructureScore.py:136: RuntimeWarning: overflow encountered in scalar multiply
#   (num_parents_states - counts.shape[1]) * var_cardinality * gammaln(1)
# /home/xj265/.local/lib/python3.10/site-packages/pgmpy/estimators/StructureScore.py:136: RuntimeWarning: overflow encountered in scalar multiply
#   (num_parents_states - counts.shape[1]) * var_cardinality * gammaln(1)
# /home/xj265/.local/lib/python3.10/site-packages/pgmpy/estimators/StructureScore.py:136: RuntimeWarning: overflow encountered in scalar multiply
#   (num_parents_states - counts.shape[1]) * var_cardinality * gammaln(1)
# /home/xj265/.local/lib/python3.10/site-packages/pgmpy/estimators/StructureScore.py:136: RuntimeWarning: overflow encountered in scalar multiply
#   (num_parents_states - counts.shape[1]) * var_cardinality * gammaln(1)
# /home/xj265/.local/lib/python3.10/site-packages/pgmpy/estimators/StructureScore.py:136: RuntimeWarning: overflow encountered in scalar multiply
#   (num_parents_states - counts.shape[1]) * var_cardinality * gammaln(1)
# /home/xj265/.local/lib/python3.10/site-packages/pgmpy/estimators/StructureScore.py:136: RuntimeWarning: overflow encountered in scalar multiply
#   (num_parents_states - counts.shape[1]) * var_cardinality * gammaln(1)
# /home/xj265/.local/lib/python3.10/site-packages/pgmpy/estimators/StructureScore.py:136: RuntimeWarning: overflow encountered in scalar multiply
#   (num_parents_states - counts.shape[1]) * var_cardinality * gammaln(1)
# /home/xj265/.local/lib/python3.10/site-packages/pgmpy/estimators/StructureScore.py:136: RuntimeWarning: overflow encountered in scalar multiply
#   (num_parents_states - counts.shape[1]) * var_cardinality * gammaln(1)
# /home/xj265/.local/lib/python3.10/site-packages/pgmpy/estimators/StructureScore.py:136: RuntimeWarning: overflow encountered in scalar multiply
#   (num_parents_states - counts.shape[1]) * var_cardinality * gammaln(1)
# /home/xj265/.local/lib/python3.10/site-packages/pgmpy/estimators/StructureScore.py:136: RuntimeWarning: overflow encountered in scalar multiply
#   (num_parents_states - counts.shape[1]) * var_cardinality * gammaln(1)
# /home/xj265/.local/lib/python3.10/site-packages/pgmpy/estimators/StructureScore.py:136: RuntimeWarning: overflow encountered in scalar multiply
#   (num_parents_states - counts.shape[1]) * var_cardinality * gammaln(1)
# /home/xj265/.local/lib/python3.10/site-packages/pgmpy/estimators/StructureScore.py:136: RuntimeWarning: overflow encountered in scalar multiply
#   (num_parents_states - counts.shape[1]) * var_cardinality * gammaln(1)
# /home/xj265/.local/lib/python3.10/site-packages/pgmpy/estimators/StructureScore.py:136: RuntimeWarning: overflow encountered in scalar multiply
#   (num_parents_states - counts.shape[1]) * var_cardinality * gammaln(1)
# /home/xj265/.local/lib/python3.10/site-packages/pgmpy/estimators/StructureScore.py:136: RuntimeWarning: overflow encountered in scalar multiply
#   (num_parents_states - counts.shape[1]) * var_cardinality * gammaln(1)
# /home/xj265/.local/lib/python3.10/site-packages/pgmpy/estimators/StructureScore.py:136: RuntimeWarning: overflow encountered in scalar multiply
#   (num_parents_states - counts.shape[1]) * var_cardinality * gammaln(1)
# /home/xj265/.local/lib/python3.10/site-packages/pgmpy/estimators/StructureScore.py:136: RuntimeWarning: overflow encountered in scalar multiply
#   (num_parents_states - counts.shape[1]) * var_cardinality * gammaln(1)
# /home/xj265/.local/lib/python3.10/site-packages/pgmpy/estimators/StructureScore.py:136: RuntimeWarning: overflow encountered in scalar multiply
#   (num_parents_states - counts.shape[1]) * var_cardinality * gammaln(1)
# /home/xj265/.local/lib/python3.10/site-packages/pgmpy/estimators/StructureScore.py:136: RuntimeWarning: overflow encountered in scalar multiply
#   (num_parents_states - counts.shape[1]) * var_cardinality * gammaln(1)
# /home/xj265/.local/lib/python3.10/site-packages/pgmpy/estimators/StructureScore.py:136: RuntimeWarning: overflow encountered in scalar multiply
#   (num_parents_states - counts.shape[1]) * var_cardinality * gammaln(1)
# /home/xj265/.local/lib/python3.10/site-packages/pgmpy/estimators/StructureScore.py:136: RuntimeWarning: overflow encountered in scalar multiply
#   (num_parents_states - counts.shape[1]) * var_cardinality * gammaln(1)
# /home/xj265/.local/lib/python3.10/site-packages/pgmpy/estimators/StructureScore.py:136: RuntimeWarning: overflow encountered in scalar multiply
#   (num_parents_states - counts.shape[1]) * var_cardinality * gammaln(1)
# /home/xj265/.local/lib/python3.10/site-packages/pgmpy/estimators/StructureScore.py:136: RuntimeWarning: overflow encountered in scalar multiply
#   (num_parents_states - counts.shape[1]) * var_cardinality * gammaln(1)
# /home/xj265/.local/lib/python3.10/site-packages/pgmpy/estimators/StructureScore.py:136: RuntimeWarning: overflow encountered in scalar multiply
#   (num_parents_states - counts.shape[1]) * var_cardinality * gammaln(1)
# /home/xj265/.local/lib/python3.10/site-packages/pgmpy/estimators/StructureScore.py:136: RuntimeWarning: overflow encountered in scalar multiply
#   (num_parents_states - counts.shape[1]) * var_cardinality * gammaln(1)
# /home/xj265/.local/lib/python3.10/site-packages/pgmpy/estimators/StructureScore.py:136: RuntimeWarning: overflow encountered in scalar multiply
#   (num_parents_states - counts.shape[1]) * var_cardinality * gammaln(1)
# /home/xj265/.local/lib/python3.10/site-packages/pgmpy/estimators/StructureScore.py:136: RuntimeWarning: overflow encountered in scalar multiply
#   (num_parents_states - counts.shape[1]) * var_cardinality * gammaln(1)
# /home/xj265/.local/lib/python3.10/site-packages/pgmpy/estimators/StructureScore.py:136: RuntimeWarning: overflow encountered in scalar multiply
#   (num_parents_states - counts.shape[1]) * var_cardinality * gammaln(1)
# /home/xj265/.local/lib/python3.10/site-packages/pgmpy/estimators/StructureScore.py:136: RuntimeWarning: overflow encountered in scalar multiply
#   (num_parents_states - counts.shape[1]) * var_cardinality * gammaln(1)
# /home/xj265/.local/lib/python3.10/site-packages/pgmpy/estimators/StructureScore.py:136: RuntimeWarning: overflow encountered in scalar multiply
#   (num_parents_states - counts.shape[1]) * var_cardinality * gammaln(1)
# /home/xj265/.local/lib/python3.10/site-packages/pgmpy/estimators/StructureScore.py:136: RuntimeWarning: overflow encountered in scalar multiply
#   (num_parents_states - counts.shape[1]) * var_cardinality * gammaln(1)
# /home/xj265/.local/lib/python3.10/site-packages/pgmpy/estimators/StructureScore.py:136: RuntimeWarning: overflow encountered in scalar multiply
#   (num_parents_states - counts.shape[1]) * var_cardinality * gammaln(1)
# /home/xj265/.local/lib/python3.10/site-packages/pgmpy/estimators/StructureScore.py:136: RuntimeWarning: overflow encountered in scalar multiply
#   (num_parents_states - counts.shape[1]) * var_cardinality * gammaln(1)
# /home/xj265/.local/lib/python3.10/site-packages/pgmpy/estimators/StructureScore.py:136: RuntimeWarning: overflow encountered in scalar multiply
#   (num_parents_states - counts.shape[1]) * var_cardinality * gammaln(1)
# /home/xj265/.local/lib/python3.10/site-packages/pgmpy/estimators/StructureScore.py:136: RuntimeWarning: overflow encountered in scalar multiply
#   (num_parents_states - counts.shape[1]) * var_cardinality * gammaln(1)
# /home/xj265/.local/lib/python3.10/site-packages/pgmpy/estimators/StructureScore.py:136: RuntimeWarning: overflow encountered in scalar multiply
#   (num_parents_states - counts.shape[1]) * var_cardinality * gammaln(1)
# /home/xj265/.local/lib/python3.10/site-packages/pgmpy/estimators/StructureScore.py:136: RuntimeWarning: overflow encountered in scalar multiply
#   (num_parents_states - counts.shape[1]) * var_cardinality * gammaln(1)
# /home/xj265/.local/lib/python3.10/site-packages/pgmpy/estimators/StructureScore.py:136: RuntimeWarning: overflow encountered in scalar multiply
#   (num_parents_states - counts.shape[1]) * var_cardinality * gammaln(1)
# /home/xj265/.local/lib/python3.10/site-packages/pgmpy/estimators/StructureScore.py:136: RuntimeWarning: overflow encountered in scalar multiply
#   (num_parents_states - counts.shape[1]) * var_cardinality * gammaln(1)
# /home/xj265/.local/lib/python3.10/site-packages/pgmpy/estimators/StructureScore.py:136: RuntimeWarning: overflow encountered in scalar multiply
#   (num_parents_states - counts.shape[1]) * var_cardinality * gammaln(1)
# /home/xj265/.local/lib/python3.10/site-packages/pgmpy/estimators/StructureScore.py:136: RuntimeWarning: overflow encountered in scalar multiply
#   (num_parents_states - counts.shape[1]) * var_cardinality * gammaln(1)
# /home/xj265/.local/lib/python3.10/site-packages/pgmpy/estimators/StructureScore.py:136: RuntimeWarning: overflow encountered in scalar multiply
#   (num_parents_states - counts.shape[1]) * var_cardinality * gammaln(1)
# /home/xj265/.local/lib/python3.10/site-packages/pgmpy/estimators/StructureScore.py:136: RuntimeWarning: overflow encountered in scalar multiply
#   (num_parents_states - counts.shape[1]) * var_cardinality * gammaln(1)
# /home/xj265/.local/lib/python3.10/site-packages/pgmpy/estimators/StructureScore.py:136: RuntimeWarning: overflow encountered in scalar multiply
#   (num_parents_states - counts.shape[1]) * var_cardinality * gammaln(1)
# /home/xj265/.local/lib/python3.10/site-packages/pgmpy/estimators/StructureScore.py:136: RuntimeWarning: overflow encountered in scalar multiply
#   (num_parents_states - counts.shape[1]) * var_cardinality * gammaln(1)
# /home/xj265/.local/lib/python3.10/site-packages/pgmpy/estimators/StructureScore.py:136: RuntimeWarning: overflow encountered in scalar multiply
#   (num_parents_states - counts.shape[1]) * var_cardinality * gammaln(1)
# /home/xj265/.local/lib/python3.10/site-packages/pgmpy/estimators/StructureScore.py:136: RuntimeWarning: overflow encountered in scalar multiply
#   (num_parents_states - counts.shape[1]) * var_cardinality * gammaln(1)
# /home/xj265/.local/lib/python3.10/site-packages/pgmpy/estimators/StructureScore.py:136: RuntimeWarning: overflow encountered in scalar multiply
#   (num_parents_states - counts.shape[1]) * var_cardinality * gammaln(1)
# /home/xj265/.local/lib/python3.10/site-packages/pgmpy/estimators/StructureScore.py:136: RuntimeWarning: overflow encountered in scalar multiply
#   (num_parents_states - counts.shape[1]) * var_cardinality * gammaln(1)
# /home/xj265/.local/lib/python3.10/site-packages/pgmpy/estimators/StructureScore.py:136: RuntimeWarning: overflow encountered in scalar multiply
#   (num_parents_states - counts.shape[1]) * var_cardinality * gammaln(1)
# /home/xj265/.local/lib/python3.10/site-packages/pgmpy/estimators/StructureScore.py:136: RuntimeWarning: overflow encountered in scalar multiply
#   (num_parents_states - counts.shape[1]) * var_cardinality * gammaln(1)
# /home/xj265/.local/lib/python3.10/site-packages/pgmpy/estimators/StructureScore.py:136: RuntimeWarning: overflow encountered in scalar multiply
#   (num_parents_states - counts.shape[1]) * var_cardinality * gammaln(1)
# /home/xj265/.local/lib/python3.10/site-packages/pgmpy/estimators/StructureScore.py:136: RuntimeWarning: overflow encountered in scalar multiply
#   (num_parents_states - counts.shape[1]) * var_cardinality * gammaln(1)
# /home/xj265/.local/lib/python3.10/site-packages/pgmpy/estimators/StructureScore.py:136: RuntimeWarning: overflow encountered in scalar multiply
#   (num_parents_states - counts.shape[1]) * var_cardinality * gammaln(1)
# /home/xj265/.local/lib/python3.10/site-packages/pgmpy/estimators/StructureScore.py:136: RuntimeWarning: overflow encountered in scalar multiply
#   (num_parents_states - counts.shape[1]) * var_cardinality * gammaln(1)
# /home/xj265/.local/lib/python3.10/site-packages/pgmpy/estimators/StructureScore.py:136: RuntimeWarning: overflow encountered in scalar multiply
#   (num_parents_states - counts.shape[1]) * var_cardinality * gammaln(1)
# /home/xj265/.local/lib/python3.10/site-packages/pgmpy/estimators/StructureScore.py:136: RuntimeWarning: overflow encountered in scalar multiply
#   (num_parents_states - counts.shape[1]) * var_cardinality * gammaln(1)
# /home/xj265/.local/lib/python3.10/site-packages/pgmpy/estimators/StructureScore.py:136: RuntimeWarning: overflow encountered in scalar multiply
#   (num_parents_states - counts.shape[1]) * var_cardinality * gammaln(1)
# /home/xj265/.local/lib/python3.10/site-packages/pgmpy/estimators/StructureScore.py:136: RuntimeWarning: overflow encountered in scalar multiply
#   (num_parents_states - counts.shape[1]) * var_cardinality * gammaln(1)
# /home/xj265/.local/lib/python3.10/site-packages/pgmpy/estimators/StructureScore.py:136: RuntimeWarning: overflow encountered in scalar multiply
#   (num_parents_states - counts.shape[1]) * var_cardinality * gammaln(1)
# /home/xj265/.local/lib/python3.10/site-packages/pgmpy/estimators/StructureScore.py:136: RuntimeWarning: overflow encountered in scalar multiply
#   (num_parents_states - counts.shape[1]) * var_cardinality * gammaln(1)
# /home/xj265/.local/lib/python3.10/site-packages/pgmpy/estimators/StructureScore.py:136: RuntimeWarning: overflow encountered in scalar multiply
#   (num_parents_states - counts.shape[1]) * var_cardinality * gammaln(1)
# /home/xj265/.local/lib/python3.10/site-packages/pgmpy/estimators/StructureScore.py:136: RuntimeWarning: overflow encountered in scalar multiply
#   (num_parents_states - counts.shape[1]) * var_cardinality * gammaln(1)
# /home/xj265/.local/lib/python3.10/site-packages/pgmpy/estimators/StructureScore.py:136: RuntimeWarning: overflow encountered in scalar multiply
#   (num_parents_states - counts.shape[1]) * var_cardinality * gammaln(1)
# /home/xj265/.local/lib/python3.10/site-packages/pgmpy/estimators/StructureScore.py:136: RuntimeWarning: overflow encountered in scalar multiply
#   (num_parents_states - counts.shape[1]) * var_cardinality * gammaln(1)
# /home/xj265/.local/lib/python3.10/site-packages/pgmpy/estimators/StructureScore.py:136: RuntimeWarning: overflow encountered in scalar multiply
#   (num_parents_states - counts.shape[1]) * var_cardinality * gammaln(1)
# /home/xj265/.local/lib/python3.10/site-packages/pgmpy/estimators/StructureScore.py:136: RuntimeWarning: overflow encountered in scalar multiply
#   (num_parents_states - counts.shape[1]) * var_cardinality * gammaln(1)
# /home/xj265/.local/lib/python3.10/site-packages/pgmpy/estimators/StructureScore.py:136: RuntimeWarning: overflow encountered in scalar multiply
#   (num_parents_states - counts.shape[1]) * var_cardinality * gammaln(1)
# /home/xj265/.local/lib/python3.10/site-packages/pgmpy/estimators/StructureScore.py:136: RuntimeWarning: overflow encountered in scalar multiply
#   (num_parents_states - counts.shape[1]) * var_cardinality * gammaln(1)
# /home/xj265/.local/lib/python3.10/site-packages/pgmpy/estimators/StructureScore.py:136: RuntimeWarning: overflow encountered in scalar multiply
#   (num_parents_states - counts.shape[1]) * var_cardinality * gammaln(1)
# /home/xj265/.local/lib/python3.10/site-packages/pgmpy/estimators/StructureScore.py:136: RuntimeWarning: overflow encountered in scalar multiply
#   (num_parents_states - counts.shape[1]) * var_cardinality * gammaln(1)
# /home/xj265/.local/lib/python3.10/site-packages/pgmpy/estimators/StructureScore.py:136: RuntimeWarning: overflow encountered in scalar multiply
#   (num_parents_states - counts.shape[1]) * var_cardinality * gammaln(1)
# /home/xj265/.local/lib/python3.10/site-packages/pgmpy/estimators/StructureScore.py:136: RuntimeWarning: overflow encountered in scalar multiply
#   (num_parents_states - counts.shape[1]) * var_cardinality * gammaln(1)
# /home/xj265/.local/lib/python3.10/site-packages/pgmpy/estimators/StructureScore.py:136: RuntimeWarning: overflow encountered in scalar multiply
#   (num_parents_states - counts.shape[1]) * var_cardinality * gammaln(1)
# /home/xj265/.local/lib/python3.10/site-packages/pgmpy/estimators/StructureScore.py:136: RuntimeWarning: overflow encountered in scalar multiply
#   (num_parents_states - counts.shape[1]) * var_cardinality * gammaln(1)
# /home/xj265/.local/lib/python3.10/site-packages/pgmpy/estimators/StructureScore.py:136: RuntimeWarning: overflow encountered in scalar multiply
#   (num_parents_states - counts.shape[1]) * var_cardinality * gammaln(1)
# /home/xj265/.local/lib/python3.10/site-packages/pgmpy/estimators/StructureScore.py:136: RuntimeWarning: overflow encountered in scalar multiply
#   (num_parents_states - counts.shape[1]) * var_cardinality * gammaln(1)
# /home/xj265/.local/lib/python3.10/site-packages/pgmpy/estimators/StructureScore.py:136: RuntimeWarning: overflow encountered in scalar multiply
#   (num_parents_states - counts.shape[1]) * var_cardinality * gammaln(1)
# /home/xj265/.local/lib/python3.10/site-packages/pgmpy/estimators/StructureScore.py:136: RuntimeWarning: overflow encountered in scalar multiply
#   (num_parents_states - counts.shape[1]) * var_cardinality * gammaln(1)
# /home/xj265/.local/lib/python3.10/site-packages/pgmpy/estimators/StructureScore.py:136: RuntimeWarning: overflow encountered in scalar multiply
#   (num_parents_states - counts.shape[1]) * var_cardinality * gammaln(1)
# /home/xj265/.local/lib/python3.10/site-packages/pgmpy/estimators/StructureScore.py:136: RuntimeWarning: overflow encountered in scalar multiply
#   (num_parents_states - counts.shape[1]) * var_cardinality * gammaln(1)
# /home/xj265/.local/lib/python3.10/site-packages/pgmpy/estimators/StructureScore.py:136: RuntimeWarning: overflow encountered in scalar multiply
#   (num_parents_states - counts.shape[1]) * var_cardinality * gammaln(1)
# /home/xj265/.local/lib/python3.10/site-packages/pgmpy/estimators/StructureScore.py:136: RuntimeWarning: overflow encountered in scalar multiply
#   (num_parents_states - counts.shape[1]) * var_cardinality * gammaln(1)
# /home/xj265/.local/lib/python3.10/site-packages/pgmpy/estimators/StructureScore.py:136: RuntimeWarning: overflow encountered in scalar multiply
#   (num_parents_states - counts.shape[1]) * var_cardinality * gammaln(1)
# /home/xj265/.local/lib/python3.10/site-packages/pgmpy/estimators/StructureScore.py:136: RuntimeWarning: overflow encountered in scalar multiply
#   (num_parents_states - counts.shape[1]) * var_cardinality * gammaln(1)
# /home/xj265/.local/lib/python3.10/site-packages/pgmpy/estimators/StructureScore.py:136: RuntimeWarning: overflow encountered in scalar multiply
#   (num_parents_states - counts.shape[1]) * var_cardinality * gammaln(1)
# /home/xj265/.local/lib/python3.10/site-packages/pgmpy/estimators/StructureScore.py:136: RuntimeWarning: overflow encountered in scalar multiply
#   (num_parents_states - counts.shape[1]) * var_cardinality * gammaln(1)
# /home/xj265/.local/lib/python3.10/site-packages/pgmpy/estimators/StructureScore.py:136: RuntimeWarning: overflow encountered in scalar multiply
#   (num_parents_states - counts.shape[1]) * var_cardinality * gammaln(1)
# /home/xj265/.local/lib/python3.10/site-packages/pgmpy/estimators/StructureScore.py:136: RuntimeWarning: overflow encountered in scalar multiply
#   (num_parents_states - counts.shape[1]) * var_cardinality * gammaln(1)
# /home/xj265/.local/lib/python3.10/site-packages/pgmpy/estimators/StructureScore.py:136: RuntimeWarning: overflow encountered in scalar multiply
#   (num_parents_states - counts.shape[1]) * var_cardinality * gammaln(1)
# /home/xj265/.local/lib/python3.10/site-packages/pgmpy/estimators/StructureScore.py:136: RuntimeWarning: overflow encountered in scalar multiply
#   (num_parents_states - counts.shape[1]) * var_cardinality * gammaln(1)
# /home/xj265/.local/lib/python3.10/site-packages/pgmpy/estimators/StructureScore.py:136: RuntimeWarning: overflow encountered in scalar multiply
#   (num_parents_states - counts.shape[1]) * var_cardinality * gammaln(1)
# /home/xj265/.local/lib/python3.10/site-packages/pgmpy/estimators/StructureScore.py:136: RuntimeWarning: overflow encountered in scalar multiply
#   (num_parents_states - counts.shape[1]) * var_cardinality * gammaln(1)
# /home/xj265/.local/lib/python3.10/site-packages/pgmpy/estimators/StructureScore.py:136: RuntimeWarning: overflow encountered in scalar multiply
#   (num_parents_states - counts.shape[1]) * var_cardinality * gammaln(1)
# /home/xj265/.local/lib/python3.10/site-packages/pgmpy/estimators/StructureScore.py:136: RuntimeWarning: overflow encountered in scalar multiply
#   (num_parents_states - counts.shape[1]) * var_cardinality * gammaln(1)
# /home/xj265/.local/lib/python3.10/site-packages/pgmpy/estimators/StructureScore.py:136: RuntimeWarning: overflow encountered in scalar multiply
#   (num_parents_states - counts.shape[1]) * var_cardinality * gammaln(1)
# /home/xj265/.local/lib/python3.10/site-packages/pgmpy/estimators/StructureScore.py:136: RuntimeWarning: overflow encountered in scalar multiply
#   (num_parents_states - counts.shape[1]) * var_cardinality * gammaln(1)
# /home/xj265/.local/lib/python3.10/site-packages/pgmpy/estimators/StructureScore.py:136: RuntimeWarning: overflow encountered in scalar multiply
#   (num_parents_states - counts.shape[1]) * var_cardinality * gammaln(1)
# /home/xj265/.local/lib/python3.10/site-packages/pgmpy/estimators/StructureScore.py:136: RuntimeWarning: overflow encountered in scalar multiply
#   (num_parents_states - counts.shape[1]) * var_cardinality * gammaln(1)
# /home/xj265/.local/lib/python3.10/site-packages/pgmpy/estimators/StructureScore.py:136: RuntimeWarning: overflow encountered in scalar multiply
#   (num_parents_states - counts.shape[1]) * var_cardinality * gammaln(1)
# /home/xj265/.local/lib/python3.10/site-packages/pgmpy/estimators/StructureScore.py:136: RuntimeWarning: overflow encountered in scalar multiply
#   (num_parents_states - counts.shape[1]) * var_cardinality * gammaln(1)
# /home/xj265/.local/lib/python3.10/site-packages/pgmpy/estimators/StructureScore.py:136: RuntimeWarning: overflow encountered in scalar multiply
#   (num_parents_states - counts.shape[1]) * var_cardinality * gammaln(1)
# /home/xj265/.local/lib/python3.10/site-packages/pgmpy/estimators/StructureScore.py:136: RuntimeWarning: overflow encountered in scalar multiply
#   (num_parents_states - counts.shape[1]) * var_cardinality * gammaln(1)
# /home/xj265/.local/lib/python3.10/site-packages/pgmpy/estimators/StructureScore.py:136: RuntimeWarning: overflow encountered in scalar multiply
#   (num_parents_states - counts.shape[1]) * var_cardinality * gammaln(1)
# /home/xj265/.local/lib/python3.10/site-packages/pgmpy/estimators/StructureScore.py:136: RuntimeWarning: overflow encountered in scalar multiply
#   (num_parents_states - counts.shape[1]) * var_cardinality * gammaln(1)
# /home/xj265/.local/lib/python3.10/site-packages/pgmpy/estimators/StructureScore.py:136: RuntimeWarning: overflow encountered in scalar multiply
#   (num_parents_states - counts.shape[1]) * var_cardinality * gammaln(1)
# /home/xj265/.local/lib/python3.10/site-packages/pgmpy/estimators/StructureScore.py:136: RuntimeWarning: overflow encountered in scalar multiply
#   (num_parents_states - counts.shape[1]) * var_cardinality * gammaln(1)
# /home/xj265/.local/lib/python3.10/site-packages/pgmpy/estimators/StructureScore.py:136: RuntimeWarning: overflow encountered in scalar multiply
#   (num_parents_states - counts.shape[1]) * var_cardinality * gammaln(1)
# /home/xj265/.local/lib/python3.10/site-packages/pgmpy/estimators/StructureScore.py:136: RuntimeWarning: overflow encountered in scalar multiply
#   (num_parents_states - counts.shape[1]) * var_cardinality * gammaln(1)
# /home/xj265/.local/lib/python3.10/site-packages/pgmpy/estimators/StructureScore.py:136: RuntimeWarning: overflow encountered in scalar multiply
#   (num_parents_states - counts.shape[1]) * var_cardinality * gammaln(1)
# /home/xj265/.local/lib/python3.10/site-packages/pgmpy/estimators/StructureScore.py:136: RuntimeWarning: overflow encountered in scalar multiply
#   (num_parents_states - counts.shape[1]) * var_cardinality * gammaln(1)
# /home/xj265/.local/lib/python3.10/site-packages/pgmpy/estimators/StructureScore.py:136: RuntimeWarning: overflow encountered in scalar multiply
#   (num_parents_states - counts.shape[1]) * var_cardinality * gammaln(1)
# /home/xj265/.local/lib/python3.10/site-packages/pgmpy/estimators/StructureScore.py:136: RuntimeWarning: overflow encountered in scalar multiply
#   (num_parents_states - counts.shape[1]) * var_cardinality * gammaln(1)
# /home/xj265/.local/lib/python3.10/site-packages/pgmpy/estimators/StructureScore.py:136: RuntimeWarning: overflow encountered in scalar multiply
#   (num_parents_states - counts.shape[1]) * var_cardinality * gammaln(1)
# /home/xj265/.local/lib/python3.10/site-packages/pgmpy/estimators/StructureScore.py:136: RuntimeWarning: overflow encountered in scalar multiply
#   (num_parents_states - counts.shape[1]) * var_cardinality * gammaln(1)
# /home/xj265/.local/lib/python3.10/site-packages/pgmpy/estimators/StructureScore.py:136: RuntimeWarning: overflow encountered in scalar multiply
#   (num_parents_states - counts.shape[1]) * var_cardinality * gammaln(1)
# /home/xj265/.local/lib/python3.10/site-packages/pgmpy/estimators/StructureScore.py:136: RuntimeWarning: overflow encountered in scalar multiply
#   (num_parents_states - counts.shape[1]) * var_cardinality * gammaln(1)
# /home/xj265/.local/lib/python3.10/site-packages/pgmpy/estimators/StructureScore.py:136: RuntimeWarning: overflow encountered in scalar multiply
#   (num_parents_states - counts.shape[1]) * var_cardinality * gammaln(1)
# /home/xj265/.local/lib/python3.10/site-packages/pgmpy/estimators/StructureScore.py:136: RuntimeWarning: overflow encountered in scalar multiply
#   (num_parents_states - counts.shape[1]) * var_cardinality * gammaln(1)
# /home/xj265/.local/lib/python3.10/site-packages/pgmpy/estimators/StructureScore.py:136: RuntimeWarning: overflow encountered in scalar multiply
#   (num_parents_states - counts.shape[1]) * var_cardinality * gammaln(1)
# /home/xj265/.local/lib/python3.10/site-packages/pgmpy/estimators/StructureScore.py:136: RuntimeWarning: overflow encountered in scalar multiply
#   (num_parents_states - counts.shape[1]) * var_cardinality * gammaln(1)
# /home/xj265/.local/lib/python3.10/site-packages/pgmpy/estimators/StructureScore.py:136: RuntimeWarning: overflow encountered in scalar multiply
#   (num_parents_states - counts.shape[1]) * var_cardinality * gammaln(1)
# /home/xj265/.local/lib/python3.10/site-packages/pgmpy/estimators/StructureScore.py:136: RuntimeWarning: overflow encountered in scalar multiply
#   (num_parents_states - counts.shape[1]) * var_cardinality * gammaln(1)
# /home/xj265/.local/lib/python3.10/site-packages/pgmpy/estimators/StructureScore.py:136: RuntimeWarning: overflow encountered in scalar multiply
#   (num_parents_states - counts.shape[1]) * var_cardinality * gammaln(1)
# /home/xj265/.local/lib/python3.10/site-packages/pgmpy/estimators/StructureScore.py:136: RuntimeWarning: overflow encountered in scalar multiply
#   (num_parents_states - counts.shape[1]) * var_cardinality * gammaln(1)
# /home/xj265/.local/lib/python3.10/site-packages/pgmpy/estimators/StructureScore.py:136: RuntimeWarning: overflow encountered in scalar multiply
#   (num_parents_states - counts.shape[1]) * var_cardinality * gammaln(1)
# /home/xj265/.local/lib/python3.10/site-packages/pgmpy/estimators/StructureScore.py:136: RuntimeWarning: overflow encountered in scalar multiply
#   (num_parents_states - counts.shape[1]) * var_cardinality * gammaln(1)
# /home/xj265/.local/lib/python3.10/site-packages/pgmpy/estimators/StructureScore.py:136: RuntimeWarning: overflow encountered in scalar multiply
#   (num_parents_states - counts.shape[1]) * var_cardinality * gammaln(1)
# /home/xj265/.local/lib/python3.10/site-packages/pgmpy/estimators/StructureScore.py:136: RuntimeWarning: overflow encountered in scalar multiply
#   (num_parents_states - counts.shape[1]) * var_cardinality * gammaln(1)
# /home/xj265/.local/lib/python3.10/site-packages/pgmpy/estimators/StructureScore.py:136: RuntimeWarning: overflow encountered in scalar multiply
#   (num_parents_states - counts.shape[1]) * var_cardinality * gammaln(1)
# /home/xj265/.local/lib/python3.10/site-packages/pgmpy/estimators/StructureScore.py:136: RuntimeWarning: overflow encountered in scalar multiply
#   (num_parents_states - counts.shape[1]) * var_cardinality * gammaln(1)
# /home/xj265/.local/lib/python3.10/site-packages/pgmpy/estimators/StructureScore.py:136: RuntimeWarning: overflow encountered in scalar multiply
#   (num_parents_states - counts.shape[1]) * var_cardinality * gammaln(1)
# /home/xj265/.local/lib/python3.10/site-packages/pgmpy/estimators/StructureScore.py:136: RuntimeWarning: overflow encountered in scalar multiply
#   (num_parents_states - counts.shape[1]) * var_cardinality * gammaln(1)
# /home/xj265/.local/lib/python3.10/site-packages/pgmpy/estimators/StructureScore.py:136: RuntimeWarning: overflow encountered in scalar multiply
#   (num_parents_states - counts.shape[1]) * var_cardinality * gammaln(1)
# /home/xj265/.local/lib/python3.10/site-packages/pgmpy/estimators/StructureScore.py:136: RuntimeWarning: overflow encountered in scalar multiply
#   (num_parents_states - counts.shape[1]) * var_cardinality * gammaln(1)
# /home/xj265/.local/lib/python3.10/site-packages/pgmpy/estimators/StructureScore.py:136: RuntimeWarning: overflow encountered in scalar multiply
#   (num_parents_states - counts.shape[1]) * var_cardinality * gammaln(1)
# /home/xj265/.local/lib/python3.10/site-packages/pgmpy/estimators/StructureScore.py:136: RuntimeWarning: overflow encountered in scalar multiply
#   (num_parents_states - counts.shape[1]) * var_cardinality * gammaln(1)
# /home/xj265/.local/lib/python3.10/site-packages/pgmpy/estimators/StructureScore.py:136: RuntimeWarning: overflow encountered in scalar multiply
#   (num_parents_states - counts.shape[1]) * var_cardinality * gammaln(1)
# /home/xj265/.local/lib/python3.10/site-packages/pgmpy/estimators/StructureScore.py:136: RuntimeWarning: overflow encountered in scalar multiply
#   (num_parents_states - counts.shape[1]) * var_cardinality * gammaln(1)
# /home/xj265/.local/lib/python3.10/site-packages/pgmpy/estimators/StructureScore.py:136: RuntimeWarning: overflow encountered in scalar multiply
#   (num_parents_states - counts.shape[1]) * var_cardinality * gammaln(1)
# /home/xj265/.local/lib/python3.10/site-packages/pgmpy/estimators/StructureScore.py:136: RuntimeWarning: overflow encountered in scalar multiply
#   (num_parents_states - counts.shape[1]) * var_cardinality * gammaln(1)
# /home/xj265/.local/lib/python3.10/site-packages/pgmpy/estimators/StructureScore.py:136: RuntimeWarning: overflow encountered in scalar multiply
#   (num_parents_states - counts.shape[1]) * var_cardinality * gammaln(1)
# /home/xj265/.local/lib/python3.10/site-packages/pgmpy/estimators/StructureScore.py:136: RuntimeWarning: overflow encountered in scalar multiply
#   (num_parents_states - counts.shape[1]) * var_cardinality * gammaln(1)
# /home/xj265/.local/lib/python3.10/site-packages/pgmpy/estimators/StructureScore.py:136: RuntimeWarning: overflow encountered in scalar multiply
#   (num_parents_states - counts.shape[1]) * var_cardinality * gammaln(1)
# /home/xj265/.local/lib/python3.10/site-packages/pgmpy/estimators/StructureScore.py:136: RuntimeWarning: overflow encountered in scalar multiply
#   (num_parents_states - counts.shape[1]) * var_cardinality * gammaln(1)
# /home/xj265/.local/lib/python3.10/site-packages/pgmpy/estimators/StructureScore.py:136: RuntimeWarning: overflow encountered in scalar multiply
#   (num_parents_states - counts.shape[1]) * var_cardinality * gammaln(1)
# /home/xj265/.local/lib/python3.10/site-packages/pgmpy/estimators/StructureScore.py:136: RuntimeWarning: overflow encountered in scalar multiply
#   (num_parents_states - counts.shape[1]) * var_cardinality * gammaln(1)
# /home/xj265/.local/lib/python3.10/site-packages/pgmpy/estimators/StructureScore.py:136: RuntimeWarning: overflow encountered in scalar multiply
#   (num_parents_states - counts.shape[1]) * var_cardinality * gammaln(1)
# /home/xj265/.local/lib/python3.10/site-packages/pgmpy/estimators/StructureScore.py:136: RuntimeWarning: overflow encountered in scalar multiply
#   (num_parents_states - counts.shape[1]) * var_cardinality * gammaln(1)
# /home/xj265/.local/lib/python3.10/site-packages/pgmpy/estimators/StructureScore.py:136: RuntimeWarning: overflow encountered in scalar multiply
#   (num_parents_states - counts.shape[1]) * var_cardinality * gammaln(1)
# /home/xj265/.local/lib/python3.10/site-packages/pgmpy/estimators/StructureScore.py:136: RuntimeWarning: overflow encountered in scalar multiply
#   (num_parents_states - counts.shape[1]) * var_cardinality * gammaln(1)
# /home/xj265/.local/lib/python3.10/site-packages/pgmpy/estimators/StructureScore.py:136: RuntimeWarning: overflow encountered in scalar multiply
#   (num_parents_states - counts.shape[1]) * var_cardinality * gammaln(1)
# /home/xj265/.local/lib/python3.10/site-packages/pgmpy/estimators/StructureScore.py:136: RuntimeWarning: overflow encountered in scalar multiply
#   (num_parents_states - counts.shape[1]) * var_cardinality * gammaln(1)
# /home/xj265/.local/lib/python3.10/site-packages/pgmpy/estimators/StructureScore.py:136: RuntimeWarning: overflow encountered in scalar multiply
#   (num_parents_states - counts.shape[1]) * var_cardinality * gammaln(1)
# /home/xj265/.local/lib/python3.10/site-packages/pgmpy/estimators/StructureScore.py:136: RuntimeWarning: overflow encountered in scalar multiply
#   (num_parents_states - counts.shape[1]) * var_cardinality * gammaln(1)
# /home/xj265/.local/lib/python3.10/site-packages/pgmpy/estimators/StructureScore.py:136: RuntimeWarning: overflow encountered in scalar multiply
#   (num_parents_states - counts.shape[1]) * var_cardinality * gammaln(1)
# /home/xj265/.local/lib/python3.10/site-packages/pgmpy/estimators/StructureScore.py:136: RuntimeWarning: overflow encountered in scalar multiply
#   (num_parents_states - counts.shape[1]) * var_cardinality * gammaln(1)
# /home/xj265/.local/lib/python3.10/site-packages/pgmpy/estimators/StructureScore.py:136: RuntimeWarning: overflow encountered in scalar multiply
#   (num_parents_states - counts.shape[1]) * var_cardinality * gammaln(1)
# /home/xj265/.local/lib/python3.10/site-packages/pgmpy/estimators/StructureScore.py:136: RuntimeWarning: overflow encountered in scalar multiply
#   (num_parents_states - counts.shape[1]) * var_cardinality * gammaln(1)
# /home/xj265/.local/lib/python3.10/site-packages/pgmpy/estimators/StructureScore.py:136: RuntimeWarning: overflow encountered in scalar multiply
#   (num_parents_states - counts.shape[1]) * var_cardinality * gammaln(1)
# /home/xj265/.local/lib/python3.10/site-packages/pgmpy/estimators/StructureScore.py:136: RuntimeWarning: overflow encountered in scalar multiply
#   (num_parents_states - counts.shape[1]) * var_cardinality * gammaln(1)
# /home/xj265/.local/lib/python3.10/site-packages/pgmpy/estimators/StructureScore.py:136: RuntimeWarning: overflow encountered in scalar multiply
#   (num_parents_states - counts.shape[1]) * var_cardinality * gammaln(1)
# /home/xj265/.local/lib/python3.10/site-packages/pgmpy/estimators/StructureScore.py:136: RuntimeWarning: overflow encountered in scalar multiply
#   (num_parents_states - counts.shape[1]) * var_cardinality * gammaln(1)
# /home/xj265/.local/lib/python3.10/site-packages/pgmpy/estimators/StructureScore.py:136: RuntimeWarning: overflow encountered in scalar multiply
#   (num_parents_states - counts.shape[1]) * var_cardinality * gammaln(1)
# /home/xj265/.local/lib/python3.10/site-packages/pgmpy/estimators/StructureScore.py:136: RuntimeWarning: overflow encountered in scalar multiply
#   (num_parents_states - counts.shape[1]) * var_cardinality * gammaln(1)
# /home/xj265/.local/lib/python3.10/site-packages/pgmpy/estimators/StructureScore.py:136: RuntimeWarning: overflow encountered in scalar multiply
#   (num_parents_states - counts.shape[1]) * var_cardinality * gammaln(1)
# /home/xj265/.local/lib/python3.10/site-packages/pgmpy/estimators/StructureScore.py:136: RuntimeWarning: overflow encountered in scalar multiply
#   (num_parents_states - counts.shape[1]) * var_cardinality * gammaln(1)
# /home/xj265/.local/lib/python3.10/site-packages/pgmpy/estimators/StructureScore.py:136: RuntimeWarning: overflow encountered in scalar multiply
#   (num_parents_states - counts.shape[1]) * var_cardinality * gammaln(1)
# /home/xj265/.local/lib/python3.10/site-packages/pgmpy/estimators/StructureScore.py:136: RuntimeWarning: overflow encountered in scalar multiply
#   (num_parents_states - counts.shape[1]) * var_cardinality * gammaln(1)
# /home/xj265/.local/lib/python3.10/site-packages/pgmpy/estimators/StructureScore.py:136: RuntimeWarning: overflow encountered in scalar multiply
#   (num_parents_states - counts.shape[1]) * var_cardinality * gammaln(1)
# /home/xj265/.local/lib/python3.10/site-packages/pgmpy/estimators/StructureScore.py:136: RuntimeWarning: overflow encountered in scalar multiply
#   (num_parents_states - counts.shape[1]) * var_cardinality * gammaln(1)
# /home/xj265/.local/lib/python3.10/site-packages/pgmpy/estimators/StructureScore.py:136: RuntimeWarning: overflow encountered in scalar multiply
#   (num_parents_states - counts.shape[1]) * var_cardinality * gammaln(1)
# /home/xj265/.local/lib/python3.10/site-packages/pgmpy/estimators/StructureScore.py:136: RuntimeWarning: overflow encountered in scalar multiply
#   (num_parents_states - counts.shape[1]) * var_cardinality * gammaln(1)
# /home/xj265/.local/lib/python3.10/site-packages/pgmpy/estimators/StructureScore.py:136: RuntimeWarning: overflow encountered in scalar multiply
#   (num_parents_states - counts.shape[1]) * var_cardinality * gammaln(1)
# /home/xj265/.local/lib/python3.10/site-packages/pgmpy/estimators/StructureScore.py:136: RuntimeWarning: overflow encountered in scalar multiply
#   (num_parents_states - counts.shape[1]) * var_cardinality * gammaln(1)
# /home/xj265/.local/lib/python3.10/site-packages/pgmpy/estimators/StructureScore.py:136: RuntimeWarning: overflow encountered in scalar multiply
#   (num_parents_states - counts.shape[1]) * var_cardinality * gammaln(1)
# /home/xj265/.local/lib/python3.10/site-packages/pgmpy/estimators/StructureScore.py:136: RuntimeWarning: overflow encountered in scalar multiply
#   (num_parents_states - counts.shape[1]) * var_cardinality * gammaln(1)
# /home/xj265/.local/lib/python3.10/site-packages/pgmpy/estimators/StructureScore.py:136: RuntimeWarning: overflow encountered in scalar multiply
#   (num_parents_states - counts.shape[1]) * var_cardinality * gammaln(1)
# /home/xj265/.local/lib/python3.10/site-packages/pgmpy/estimators/StructureScore.py:136: RuntimeWarning: overflow encountered in scalar multiply
#   (num_parents_states - counts.shape[1]) * var_cardinality * gammaln(1)
# ...
# /home/xj265/.local/lib/python3.10/site-packages/pgmpy/estimators/StructureScore.py:136: RuntimeWarning: overflow encountered in scalar multiply
#   (num_parents_states - counts.shape[1]) * var_cardinality * gammaln(1)
# /home/xj265/.local/lib/python3.10/site-packages/pgmpy/estimators/StructureScore.py:136: RuntimeWarning: overflow encountered in scalar multiply
#   (num_parents_states - counts.shape[1]) * var_cardinality * gammaln(1)
# /home/xj265/.local/lib/python3.10/site-packages/pgmpy/estimators/StructureScore.py:136: RuntimeWarning: overflow encountered in scalar multiply
#   (num_parents_states - counts.shape[1]) * var_cardinality * gammaln(1)
# /home/xj265/.local/lib/python3.10/site-packages/pgmpy/estimators/StructureScore.py:136: RuntimeWarning: overflow encountered in scalar multiply
#   (num_parents_states - counts.shape[1]) * var_cardinality * gammaln(1)
# /home/xj265/.local/lib/python3.10/site-packages/pgmpy/estimators/StructureScore.py:136: RuntimeWarning: overflow encountered in scalar multiply
#   (num_parents_states - counts.shape[1]) * var_cardinality * gammaln(1)
# /home/xj265/.local/lib/python3.10/site-packages/pgmpy/estimators/StructureScore.py:136: RuntimeWarning: overflow encountered in scalar multiply
#   (num_parents_states - counts.shape[1]) * var_cardinality * gammaln(1)
# /home/xj265/.local/lib/python3.10/site-packages/pgmpy/estimators/StructureScore.py:136: RuntimeWarning: overflow encountered in scalar multiply
#   (num_parents_states - counts.shape[1]) * var_cardinality * gammaln(1)
# /home/xj265/.local/lib/python3.10/site-packages/pgmpy/estimators/StructureScore.py:136: RuntimeWarning: overflow encountered in scalar multiply
#   (num_parents_states - counts.shape[1]) * var_cardinality * gammaln(1)
# /home/xj265/.local/lib/python3.10/site-packages/pgmpy/estimators/StructureScore.py:136: RuntimeWarning: overflow encountered in scalar multiply
#   (num_parents_states - counts.shape[1]) * var_cardinality * gammaln(1)
# /home/xj265/.local/lib/python3.10/site-packages/pgmpy/estimators/StructureScore.py:136: RuntimeWarning: overflow encountered in scalar multiply
#   (num_parents_states - counts.shape[1]) * var_cardinality * gammaln(1)
# /home/xj265/.local/lib/python3.10/site-packages/pgmpy/estimators/StructureScore.py:136: RuntimeWarning: overflow encountered in scalar multiply
#   (num_parents_states - counts.shape[1]) * var_cardinality * gammaln(1)
# /home/xj265/.local/lib/python3.10/site-packages/pgmpy/estimators/StructureScore.py:136: RuntimeWarning: overflow encountered in scalar multiply
#   (num_parents_states - counts.shape[1]) * var_cardinality * gammaln(1)
# /home/xj265/.local/lib/python3.10/site-packages/pgmpy/estimators/StructureScore.py:136: RuntimeWarning: overflow encountered in scalar multiply
#   (num_parents_states - counts.shape[1]) * var_cardinality * gammaln(1)
# /home/xj265/.local/lib/python3.10/site-packages/pgmpy/estimators/StructureScore.py:136: RuntimeWarning: overflow encountered in scalar multiply
#   (num_parents_states - counts.shape[1]) * var_cardinality * gammaln(1)
# /home/xj265/.local/lib/python3.10/site-packages/pgmpy/estimators/StructureScore.py:136: RuntimeWarning: overflow encountered in scalar multiply
#   (num_parents_states - counts.shape[1]) * var_cardinality * gammaln(1)
# /home/xj265/.local/lib/python3.10/site-packages/pgmpy/estimators/StructureScore.py:136: RuntimeWarning: overflow encountered in scalar multiply
#   (num_parents_states - counts.shape[1]) * var_cardinality * gammaln(1)
# /home/xj265/.local/lib/python3.10/site-packages/pgmpy/estimators/StructureScore.py:136: RuntimeWarning: overflow encountered in scalar multiply
#   (num_parents_states - counts.shape[1]) * var_cardinality * gammaln(1)
# /home/xj265/.local/lib/python3.10/site-packages/pgmpy/estimators/StructureScore.py:136: RuntimeWarning: overflow encountered in scalar multiply
#   (num_parents_states - counts.shape[1]) * var_cardinality * gammaln(1)
# /home/xj265/.local/lib/python3.10/site-packages/pgmpy/estimators/StructureScore.py:136: RuntimeWarning: overflow encountered in scalar multiply
#   (num_parents_states - counts.shape[1]) * var_cardinality * gammaln(1)
# /home/xj265/.local/lib/python3.10/site-packages/pgmpy/estimators/StructureScore.py:136: RuntimeWarning: overflow encountered in scalar multiply
#   (num_parents_states - counts.shape[1]) * var_cardinality * gammaln(1)
# /home/xj265/.local/lib/python3.10/site-packages/pgmpy/estimators/StructureScore.py:136: RuntimeWarning: overflow encountered in scalar multiply
#   (num_parents_states - counts.shape[1]) * var_cardinality * gammaln(1)
# /home/xj265/.local/lib/python3.10/site-packages/pgmpy/estimators/StructureScore.py:136: RuntimeWarning: overflow encountered in scalar multiply
#   (num_parents_states - counts.shape[1]) * var_cardinality * gammaln(1)
# /home/xj265/.local/lib/python3.10/site-packages/pgmpy/estimators/StructureScore.py:136: RuntimeWarning: overflow encountered in scalar multiply
#   (num_parents_states - counts.shape[1]) * var_cardinality * gammaln(1)
# /home/xj265/.local/lib/python3.10/site-packages/pgmpy/estimators/StructureScore.py:136: RuntimeWarning: overflow encountered in scalar multiply
#   (num_parents_states - counts.shape[1]) * var_cardinality * gammaln(1)
# /home/xj265/.local/lib/python3.10/site-packages/pgmpy/estimators/StructureScore.py:136: RuntimeWarning: overflow encountered in scalar multiply
#   (num_parents_states - counts.shape[1]) * var_cardinality * gammaln(1)
# /home/xj265/.local/lib/python3.10/site-packages/pgmpy/estimators/StructureScore.py:136: RuntimeWarning: overflow encountered in scalar multiply
#   (num_parents_states - counts.shape[1]) * var_cardinality * gammaln(1)
# /home/xj265/.local/lib/python3.10/site-packages/pgmpy/estimators/StructureScore.py:136: RuntimeWarning: overflow encountered in scalar multiply
#   (num_parents_states - counts.shape[1]) * var_cardinality * gammaln(1)
# /home/xj265/.local/lib/python3.10/site-packages/pgmpy/estimators/StructureScore.py:136: RuntimeWarning: overflow encountered in scalar multiply
#   (num_parents_states - counts.shape[1]) * var_cardinality * gammaln(1)
# /home/xj265/.local/lib/python3.10/site-packages/pgmpy/estimators/StructureScore.py:136: RuntimeWarning: overflow encountered in scalar multiply
#   (num_parents_states - counts.shape[1]) * var_cardinality * gammaln(1)
# /home/xj265/.local/lib/python3.10/site-packages/pgmpy/estimators/StructureScore.py:136: RuntimeWarning: overflow encountered in scalar multiply
#   (num_parents_states - counts.shape[1]) * var_cardinality * gammaln(1)
# /home/xj265/.local/lib/python3.10/site-packages/pgmpy/estimators/StructureScore.py:136: RuntimeWarning: overflow encountered in scalar multiply
#   (num_parents_states - counts.shape[1]) * var_cardinality * gammaln(1)
# /home/xj265/.local/lib/python3.10/site-packages/pgmpy/estimators/StructureScore.py:136: RuntimeWarning: overflow encountered in scalar multiply
#   (num_parents_states - counts.shape[1]) * var_cardinality * gammaln(1)
# /home/xj265/.local/lib/python3.10/site-packages/pgmpy/estimators/StructureScore.py:136: RuntimeWarning: overflow encountered in scalar multiply
#   (num_parents_states - counts.shape[1]) * var_cardinality * gammaln(1)
# /home/xj265/.local/lib/python3.10/site-packages/pgmpy/estimators/StructureScore.py:136: RuntimeWarning: overflow encountered in scalar multiply
#   (num_parents_states - counts.shape[1]) * var_cardinality * gammaln(1)
# /home/xj265/.local/lib/python3.10/site-packages/pgmpy/estimators/StructureScore.py:136: RuntimeWarning: overflow encountered in scalar multiply
#   (num_parents_states - counts.shape[1]) * var_cardinality * gammaln(1)
# /home/xj265/.local/lib/python3.10/site-packages/pgmpy/estimators/StructureScore.py:136: RuntimeWarning: overflow encountered in scalar multiply
#   (num_parents_states - counts.shape[1]) * var_cardinality * gammaln(1)
# /home/xj265/.local/lib/python3.10/site-packages/pgmpy/estimators/StructureScore.py:136: RuntimeWarning: overflow encountered in scalar multiply
#   (num_parents_states - counts.shape[1]) * var_cardinality * gammaln(1)
# /home/xj265/.local/lib/python3.10/site-packages/pgmpy/estimators/StructureScore.py:136: RuntimeWarning: overflow encountered in scalar multiply
#   (num_parents_states - counts.shape[1]) * var_cardinality * gammaln(1)
# /home/xj265/.local/lib/python3.10/site-packages/pgmpy/estimators/StructureScore.py:136: RuntimeWarning: overflow encountered in scalar multiply
#   (num_parents_states - counts.shape[1]) * var_cardinality * gammaln(1)
# /home/xj265/.local/lib/python3.10/site-packages/pgmpy/estimators/StructureScore.py:136: RuntimeWarning: overflow encountered in scalar multiply
#   (num_parents_states - counts.shape[1]) * var_cardinality * gammaln(1)
# /home/xj265/.local/lib/python3.10/site-packages/pgmpy/estimators/StructureScore.py:136: RuntimeWarning: overflow encountered in scalar multiply
#   (num_parents_states - counts.shape[1]) * var_cardinality * gammaln(1)
# /home/xj265/.local/lib/python3.10/site-packages/pgmpy/estimators/StructureScore.py:136: RuntimeWarning: overflow encountered in scalar multiply
#   (num_parents_states - counts.shape[1]) * var_cardinality * gammaln(1)
# /home/xj265/.local/lib/python3.10/site-packages/pgmpy/estimators/StructureScore.py:136: RuntimeWarning: overflow encountered in scalar multiply
#   (num_parents_states - counts.shape[1]) * var_cardinality * gammaln(1)
# /home/xj265/.local/lib/python3.10/site-packages/pgmpy/estimators/StructureScore.py:136: RuntimeWarning: overflow encountered in scalar multiply
#   (num_parents_states - counts.shape[1]) * var_cardinality * gammaln(1)
# /home/xj265/.local/lib/python3.10/site-packages/pgmpy/estimators/StructureScore.py:136: RuntimeWarning: overflow encountered in scalar multiply
#   (num_parents_states - counts.shape[1]) * var_cardinality * gammaln(1)
# /home/xj265/.local/lib/python3.10/site-packages/pgmpy/estimators/StructureScore.py:136: RuntimeWarning: overflow encountered in scalar multiply
#   (num_parents_states - counts.shape[1]) * var_cardinality * gammaln(1)
# /home/xj265/.local/lib/python3.10/site-packages/pgmpy/estimators/StructureScore.py:136: RuntimeWarning: overflow encountered in scalar multiply
#   (num_parents_states - counts.shape[1]) * var_cardinality * gammaln(1)
# /home/xj265/.local/lib/python3.10/site-packages/pgmpy/estimators/StructureScore.py:136: RuntimeWarning: overflow encountered in scalar multiply
#   (num_parents_states - counts.shape[1]) * var_cardinality * gammaln(1)
# /home/xj265/.local/lib/python3.10/site-packages/pgmpy/estimators/StructureScore.py:136: RuntimeWarning: overflow encountered in scalar multiply
#   (num_parents_states - counts.shape[1]) * var_cardinality * gammaln(1)
# /home/xj265/.local/lib/python3.10/site-packages/pgmpy/estimators/StructureScore.py:136: RuntimeWarning: overflow encountered in scalar multiply
#   (num_parents_states - counts.shape[1]) * var_cardinality * gammaln(1)
# /home/xj265/.local/lib/python3.10/site-packages/pgmpy/estimators/StructureScore.py:136: RuntimeWarning: overflow encountered in scalar multiply
#   (num_parents_states - counts.shape[1]) * var_cardinality * gammaln(1)
# /home/xj265/.local/lib/python3.10/site-packages/pgmpy/estimators/StructureScore.py:136: RuntimeWarning: overflow encountered in scalar multiply
#   (num_parents_states - counts.shape[1]) * var_cardinality * gammaln(1)
# /home/xj265/.local/lib/python3.10/site-packages/pgmpy/estimators/StructureScore.py:136: RuntimeWarning: overflow encountered in scalar multiply
#   (num_parents_states - counts.shape[1]) * var_cardinality * gammaln(1)
# /home/xj265/.local/lib/python3.10/site-packages/pgmpy/estimators/StructureScore.py:136: RuntimeWarning: overflow encountered in scalar multiply
#   (num_parents_states - counts.shape[1]) * var_cardinality * gammaln(1)
# /home/xj265/.local/lib/python3.10/site-packages/pgmpy/estimators/StructureScore.py:136: RuntimeWarning: overflow encountered in scalar multiply
#   (num_parents_states - counts.shape[1]) * var_cardinality * gammaln(1)
# /home/xj265/.local/lib/python3.10/site-packages/pgmpy/estimators/StructureScore.py:136: RuntimeWarning: overflow encountered in scalar multiply
#   (num_parents_states - counts.shape[1]) * var_cardinality * gammaln(1)
# /home/xj265/.local/lib/python3.10/site-packages/pgmpy/estimators/StructureScore.py:136: RuntimeWarning: overflow encountered in scalar multiply
#   (num_parents_states - counts.shape[1]) * var_cardinality * gammaln(1)
# /home/xj265/.local/lib/python3.10/site-packages/pgmpy/estimators/StructureScore.py:136: RuntimeWarning: overflow encountered in scalar multiply
#   (num_parents_states - counts.shape[1]) * var_cardinality * gammaln(1)
# /home/xj265/.local/lib/python3.10/site-packages/pgmpy/estimators/StructureScore.py:136: RuntimeWarning: overflow encountered in scalar multiply
#   (num_parents_states - counts.shape[1]) * var_cardinality * gammaln(1)
# /home/xj265/.local/lib/python3.10/site-packages/pgmpy/estimators/StructureScore.py:136: RuntimeWarning: overflow encountered in scalar multiply
#   (num_parents_states - counts.shape[1]) * var_cardinality * gammaln(1)
# /home/xj265/.local/lib/python3.10/site-packages/pgmpy/estimators/StructureScore.py:136: RuntimeWarning: overflow encountered in scalar multiply
#   (num_parents_states - counts.shape[1]) * var_cardinality * gammaln(1)
# /home/xj265/.local/lib/python3.10/site-packages/pgmpy/estimators/StructureScore.py:136: RuntimeWarning: overflow encountered in scalar multiply
#   (num_parents_states - counts.shape[1]) * var_cardinality * gammaln(1)
# /home/xj265/.local/lib/python3.10/site-packages/pgmpy/estimators/StructureScore.py:136: RuntimeWarning: overflow encountered in scalar multiply
#   (num_parents_states - counts.shape[1]) * var_cardinality * gammaln(1)
# /home/xj265/.local/lib/python3.10/site-packages/pgmpy/estimators/StructureScore.py:136: RuntimeWarning: overflow encountered in scalar multiply
#   (num_parents_states - counts.shape[1]) * var_cardinality * gammaln(1)
# /home/xj265/.local/lib/python3.10/site-packages/pgmpy/estimators/StructureScore.py:136: RuntimeWarning: overflow encountered in scalar multiply
#   (num_parents_states - counts.shape[1]) * var_cardinality * gammaln(1)
# /home/xj265/.local/lib/python3.10/site-packages/pgmpy/estimators/StructureScore.py:136: RuntimeWarning: overflow encountered in scalar multiply
#   (num_parents_states - counts.shape[1]) * var_cardinality * gammaln(1)
# /home/xj265/.local/lib/python3.10/site-packages/pgmpy/estimators/StructureScore.py:136: RuntimeWarning: overflow encountered in scalar multiply
#   (num_parents_states - counts.shape[1]) * var_cardinality * gammaln(1)
# /home/xj265/.local/lib/python3.10/site-packages/pgmpy/estimators/StructureScore.py:136: RuntimeWarning: overflow encountered in scalar multiply
#   (num_parents_states - counts.shape[1]) * var_cardinality * gammaln(1)
# /home/xj265/.local/lib/python3.10/site-packages/pgmpy/estimators/StructureScore.py:136: RuntimeWarning: overflow encountered in scalar multiply
#   (num_parents_states - counts.shape[1]) * var_cardinality * gammaln(1)
# /home/xj265/.local/lib/python3.10/site-packages/pgmpy/estimators/StructureScore.py:136: RuntimeWarning: overflow encountered in scalar multiply
#   (num_parents_states - counts.shape[1]) * var_cardinality * gammaln(1)
# /home/xj265/.local/lib/python3.10/site-packages/pgmpy/estimators/StructureScore.py:136: RuntimeWarning: overflow encountered in scalar multiply
#   (num_parents_states - counts.shape[1]) * var_cardinality * gammaln(1)
# /home/xj265/.local/lib/python3.10/site-packages/pgmpy/estimators/StructureScore.py:136: RuntimeWarning: overflow encountered in scalar multiply
#   (num_parents_states - counts.shape[1]) * var_cardinality * gammaln(1)
# /home/xj265/.local/lib/python3.10/site-packages/pgmpy/estimators/StructureScore.py:136: RuntimeWarning: overflow encountered in scalar multiply
#   (num_parents_states - counts.shape[1]) * var_cardinality * gammaln(1)
# /home/xj265/.local/lib/python3.10/site-packages/pgmpy/estimators/StructureScore.py:136: RuntimeWarning: overflow encountered in scalar multiply
#   (num_parents_states - counts.shape[1]) * var_cardinality * gammaln(1)

# %% [markdown]
# ## LiM algorithm

# %%
import lingam

model = lingam.LiM()
dis_con = np.full((1, df.shape[1]), 0)
dis_con[0, [0, 1]] = 1
model.fit(df.values, dis_con=dis_con, only_global=True)
# Out:
# /home/xj265/.local/lib/python3.10/site-packages/lingam/lim.py:119: RuntimeWarning: overflow encountered in cosh
#   loss_con = np.sum(-np.log(np.cosh(R)) * dis_con)
# /home/xj265/.local/lib/python3.10/site-packages/lingam/lim.py:119: RuntimeWarning: invalid value encountered in multiply
#   loss_con = np.sum(-np.log(np.cosh(R)) * dis_con)
# /home/xj265/.local/lib/python3.10/site-packages/numpy/linalg/linalg.py:680: RuntimeWarning: overflow encountered in matmul
#   result = z if result is None else fmatmul(result, z)
# /home/xj265/.local/lib/python3.10/site-packages/numpy/linalg/linalg.py:677: RuntimeWarning: overflow encountered in matmul
#   z = a if z is None else fmatmul(z, z)
# /home/xj265/.local/lib/python3.10/site-packages/lingam/lim.py:251: RuntimeWarning: invalid value encountered in multiply
#   h = (G_h.T * M).sum() - d
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 6
#       4 dis_con = np.full((1, df.shape[1]), 0)
#       5 dis_con[0, [0, 1]] = 1
# ----> 6 model.fit(df.values, dis_con=dis_con, only_global=True)
#
# File ~/.local/lib/python3.10/site-packages/lingam/lim.py:89, in LiM.fit(self, X, dis_con, only_global, is_poisson)
#      64 def fit(self, X, dis_con, only_global=False, is_poisson=False):
#      65     """Fit the model to X with mixed data.
#      66
#      67     Parameters
#    (...)
#      86         Returns the instance of self.
#      87     """
# ---> 89     W_min_lss = self._estimate_LiM(X, dis_con, only_global, is_poisson)
#      90     self._adjacency_matrix = W_min_lss
#      91     return self._adjacency_matrix
#
# File ~/.local/lib/python3.10/site-packages/lingam/lim.py:298, in LiM._estimate_LiM(self, X, dis_con, only_global, is_poisson)
#     296 w_new, h_new = None, None
#     297 while rho < self._rho_max:
# --> 298     sol = sopt.minimize(
#     299         _func, w_est, method="L-BFGS-B", jac=True, bounds=bnds
#     300     )
#     301     # print('--- One iteration passed.....', sol.fun)
#     302     w_new = sol.x
#
# File ~/.local/lib/python3.10/site-packages/scipy/optimize/_minimize.py:710, in minimize(fun, x0, args, method, jac, hess, hessp, bounds, constraints, tol, callback, options)
#     707     res = _minimize_newtoncg(fun, x0, args, jac, hess, hessp, callback,
#     708                              **options)
#     709 elif meth == 'l-bfgs-b':
# --> 710     res = _minimize_lbfgsb(fun, x0, args, jac, bounds,
#     711                            callback=callback, **options)
#     712 elif meth == 'tnc':
#     713     res = _minimize_tnc(fun, x0, args, jac, bounds, callback=callback,
#     714                         **options)
#
# File ~/.local/lib/python3.10/site-packages/scipy/optimize/_lbfgsb_py.py:365, in _minimize_lbfgsb(fun, x0, args, jac, bounds, disp, maxcor, ftol, gtol, eps, maxfun, maxiter, iprint, callback, maxls, finite_diff_rel_step, **unknown_options)
#     359 task_str = task.tobytes()
#     360 if task_str.startswith(b'FG'):
#     361     # The minimization routine wants f and g at the current x.
#     362     # Note that interruptions due to maxfun are postponed
#     363     # until the completion of the current minimization iteration.
#     364     # Overwrite f and g:
# --> 365     f, g = func_and_grad(x)
#     366 elif task_str.startswith(b'NEW_X'):
#     367     # new iteration
#     368     n_iterations += 1
#
# File ~/.local/lib/python3.10/site-packages/scipy/optimize/_differentiable_functions.py:285, in ScalarFunction.fun_and_grad(self, x)
#     283 if not np.array_equal(x, self.x):
#     284     self._update_x_impl(x)
# --> 285 self._update_fun()
#     286 self._update_grad()
#     287 return self.f, self.g
#
# File ~/.local/lib/python3.10/site-packages/scipy/optimize/_differentiable_functions.py:251, in ScalarFunction._update_fun(self)
#     249 def _update_fun(self):
#     250     if not self.f_updated:
# --> 251         self._update_fun_impl()
#     252         self.f_updated = True
#
# File ~/.local/lib/python3.10/site-packages/scipy/optimize/_differentiable_functions.py:155, in ScalarFunction.__init__.<locals>.update_fun()
#     154 def update_fun():
# --> 155     self.f = fun_wrapped(self.x)
#
# File ~/.local/lib/python3.10/site-packages/scipy/optimize/_differentiable_functions.py:137, in ScalarFunction.__init__.<locals>.fun_wrapped(x)
#     133 self.nfev += 1
#     134 # Send a copy because the user may overwrite it.
#     135 # Overwriting results in undefined behaviour because
#     136 # fun(self.x) will change self.x, with the two no longer linked.
# --> 137 fx = fun(np.copy(x), *args)
#     138 # Make sure the function returns a true scalar
#     139 if not np.isscalar(fx):
#
# File ~/.local/lib/python3.10/site-packages/scipy/optimize/_optimize.py:77, in MemoizeJac.__call__(self, x, *args)
#      75 def __call__(self, x, *args):
#      76     """ returns the function value """
# ---> 77     self._compute_if_needed(x, *args)
#      78     return self._value
#
# File ~/.local/lib/python3.10/site-packages/scipy/optimize/_optimize.py:71, in MemoizeJac._compute_if_needed(self, x, *args)
#      69 if not np.all(x == self.x) or self._value is None or self.jac is None:
#      70     self.x = np.asarray(x).copy()
# ---> 71     fg = self.fun(x, *args)
#      72     self.jac = fg[1]
#      73     self._value = fg[0]
#
# File ~/.local/lib/python3.10/site-packages/lingam/lim.py:261, in LiM._estimate_LiM.<locals>._func(w)
#     259 """Evaluate value and gradient of augmented Lagrangian for doubled variables ([2 d^2] array)."""
#     260 W = _adj(w)
# --> 261 loss, G_loss = _loss(W)
#     262 h, G_h = _h(W)
#     263 obj = loss + 0.5 * rho * h * h + alpha * h + self._lambda1 * w.sum()
#
# File ~/.local/lib/python3.10/site-packages/lingam/lim.py:99, in LiM._estimate_LiM.<locals>._loss(W)
#      97 """Evaluate value and gradient of loss."""
#      98 M = X @ W
# ---> 99 if self._loss_type == "logistic":
#     100     loss = 1.0 / X.shape[0] * (np.logaddexp(0, M) - X * M).sum()
#     101     G_loss = 1.0 / X.shape[0] * X.T @ (sigmoid(M) - X)
#
# KeyboardInterrupt:
